# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import scipy.stats as stats
from scipy.stats import ttest_rel

# %% [markdown]
# Read in files and perform statistical tests of independence for Pearson scores at each walk length

# %%
# Read data
main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/'
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v2/scrambled_dataset/'
file_list = Path(main_path).glob('*batch??.csv')
for file in file_list:
    print(file)
    df = pd.read_csv(file)
    # ,ave to a copy of df, then perform Fisher's r to z transformation on Pearson scores
    df_z = df.copy()
    for i in range(1, 6):
        df_z[str(i)] = np.arctanh(df_z[str(i)])
    # print(df_z)
    print(file.stem)
    # compare difference in score between Recon methods for each walk length column
    for i in range(1, 6):
        print('Walk Length: '+str(i))
        # get unique values of Recon column
        recon_list = df['Recon'].unique()
        df_stats_all = pd.DataFrame()
        df_stats = pd.DataFrame()
        # loop through each unique value of Recon column
        for recon in recon_list:
            print(recon)
            print(df[df['Recon'] == str(recon)][str(i)])
            print('Statistics for '+str(recon))
            print('Mean')
            print(df[df['Recon'] == str(recon)][str(i)].mean())
            print('Stdev')
            print(df[df['Recon'] == str(recon)][str(i)].std())
            print('Median')
            print(df[df['Recon'] == str(recon)][str(i)].median())
            print('IQR')
            print(df[df['Recon'] == str(recon)][str(i)].quantile(
                q=0.75)-df[df['Recon'] == str(recon)][str(i)].quantile(q=0.25))
            # combine statistics from each Recon method into dataframe
            df_stats = pd.DataFrame({'Recon': recon_list, 'Mean': df[df['Recon'] == str(recon)][str(i)].mean(), 'Stdev': df[df['Recon'] == str(recon)][str(i)].std(
            ), 'Median': df[df['Recon'] == str(recon)][str(i)].median(), 'IQR': df[df['Recon'] == str(recon)][str(i)].quantile(q=0.75)-df[df['Recon'] == str(recon)][str(i)].quantile(q=0.25)})
            # combine df_stats from each Recon method into dataframe
            df_stats_all = pd.concat([df_stats, df_stats_all], axis=0)
        print(df_stats_all)
        # save dataframe to csv
        df_stats_all.to_csv(main_path+'/stats/'+file.stem +
                            '_walk_length_'+str(i)+'_stats.csv', index=False)
        # calculate p-value for difference in score between Recon methods in recon_list, with comparisons between each pair of Recon methods, save all statistics and p-values to csv
        df_ttest_results = pd.DataFrame()
        df_ttest_rel_results = pd.DataFrame()
        df_z_ttest_results = pd.DataFrame()
        df_z_ttest_rel_results = pd.DataFrame()
        for recon in recon_list:
            for recon2 in recon_list:
                if recon != recon2:
                    print(recon)
                    print(recon2)
                    # print the length of df for each Recon method
                    print(len(df[df['Recon'] == str(recon)][str(i)]))
                    print(len(df[df['Recon'] == str(recon2)][str(i)]))
                    # calculate t-test on Pearson scores, get t-statistic and p-value
                    ttest_pearson_score = stats.ttest_ind(df[df['Recon'] == str(
                        recon)][str(i)], df[df['Recon'] == str(recon2)][str(i)], alternative='less', nan_policy='propagate')
                    ttest_rel_pearson_score = ttest_rel(df[df['Recon'] == str(
                        recon)][str(i)], df[df['Recon'] == str(recon2)][str(i)], alternative='less', nan_policy='propagate')
                    ttest_z_score = stats.ttest_ind(df_z[df_z['Recon'] == str(
                        recon)][str(i)], df_z[df_z['Recon'] == str(recon2)][str(i)], alternative='less', nan_policy='propagate')
                    ttest_rel_z_score = ttest_rel(df_z[df_z['Recon'] == str(
                        recon)][str(i)], df_z[df_z['Recon'] == str(recon2)][str(i)], alternative='less', nan_policy='propagate')
                    # combine t-test results into dataframe
                    df_ttest_results = pd.concat([df_ttest_results, pd.DataFrame({'Recon 1': recon, 'Recon 2': recon2, 'T-statistic Pearson Score t-test': ttest_pearson_score[0],
                                                 'p-value Pearson Score t-test':ttest_pearson_score[1]}, index=[0])], axis=0)  # ,'T-statistic z-score':ttest_z_score[0],'p-value z-score':ttest_z_score[1]
                    df_ttest_rel_results = pd.concat([df_ttest_rel_results, pd.DataFrame({'Recon 1': recon, 'Recon 2': recon2, 'T-statistic Pearson Score t-test': ttest_rel_pearson_score[0],
                                                                                          'p-value Pearson Score t-test':ttest_rel_pearson_score[1]}, index=[0])], axis=0)  # ,'T-statistic z-score':ttest_z_score[0],'p-value z-score':ttest_z_score[1]
                    df_z_ttest_rel_results = pd.concat([df_z_ttest_rel_results, pd.DataFrame({'Recon 1': recon, 'Recon 2': recon2, 'T-statistic z-score t-test': ttest_rel_z_score[0],
                                                                                              'p-value z-score t-test':ttest_rel_z_score[1]}, index=[0])], axis=0)  # ,'T-statistic z-score':ttest_z_score[0],'p-value z-score':ttest_z_score[1]
                    df_z_ttest_results = pd.concat([df_z_ttest_results, pd.DataFrame({'Recon 1': recon, 'Recon 2': recon2, 'T-statistic z-score t-test': ttest_z_score[0],
                                                    'p-value z-score t-test':ttest_z_score[1]}, index=[0])], axis=0)  # ,'T-statistic z-score':ttest_z_score[0],'p-value z-score':ttest_z_score[1]
        print('T-test ind results')
        print(df_ttest_results)
        print('T-test rel results')
        print(df_ttest_rel_results)
        print('T-test ind z-score results')
        print(df_z_ttest_results)
        print('T-test rel z-score results')
        print(df_z_ttest_rel_results)

        # save dataframe to csv
        df_ttest_results.to_csv(
            main_path+'/stats/'+file.stem+'_walk_length_'+str(i)+'_ttest_results.csv', index=False)
        df_ttest_rel_results.to_csv(
            main_path+'/stats/'+file.stem+'_walk_length_'+str(i)+'_ttest_rel_results.csv', index=False)
        df_z_ttest_results.to_csv(
            main_path+'/stats/'+file.stem+'_walk_length_'+str(i)+'_z_score_ttest_results.csv', index=False)
        df_z_ttest_rel_results.to_csv(
            main_path+'/stats/'+file.stem+'_walk_length_'+str(i)+'_z_score_ttest_rel_results.csv', index=False)
        # # calculate non-parametric statistics for difference in score between Recon methods in recon_list, with comparisons between each pair of Recon methods, save all statistics and p-values to csv
        # df_mannwhitneyu_results = pd.DataFrame()
        # for recon in recon_list:
        #     for recon2 in recon_list:
        #         if recon != recon2:
        #             # print(recon)
        #             # print(recon2)
        #             # print(stats.mannwhitneyu(df[df['Recon']==str(recon)][str(i)],df[df['Recon']==str(recon2)][str(i)]))
        #             # calculate Mann-Whitney U test on Pearson scores, get U-statistic and p-value
        #             mannwhitneyu = stats.mannwhitneyu(df[df['Recon'] == str(
        #                 recon)][str(i)], df[df['Recon'] == str(recon2)][str(i)])
        #             # # calculate Mann-Whitney U test on Fisher's r to z transformed Pearson scores, get U-statistic and p-value
        #             # mannwhitneyu_z = stats.mannwhitneyu(df_z[df_z['Recon']==str(recon)]['z'],df_z[df_z['Recon']==str(recon2)]['z'])
        #             # combine Mann-Whitney U test results into dataframe
        #             # , 'U-statistic z-score':mannwhitneyu_z[0],'p-value z-score':mannwhitneyu_z[1]
        #             df_mannwhitneyu_results = pd.concat([df_mannwhitneyu_results, pd.DataFrame(
        #                 {'Recon 1': recon, 'Recon 2': recon2, 'U-statistic Pearson Score Mann-Whitney': mannwhitneyu[0], 'p-value Pearson Score Mann-Whitney':mannwhitneyu[1]}, index=[0])], axis=0)
        # # save dataframe to csv
        # df_mannwhitneyu_results.to_csv(
        #     main_path+'/'+file.stem+'_walk_length_'+str(i)+'_mannwhitneyu_results.csv', index=False)
# Out:
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch41.csv
# count_all_batch41
# Walk Length: 1
# MSMT CSD SIFT2 Streamline Count
# 0     0.613709
# 1     0.615947
# 2     0.459425
# 3     0.537682
# 4     0.661649
# 5     0.422555
# 6     0.603934
# 7     0.622703
# 8     0.634884
# 9     0.628968
# 10    0.575197
# 11    0.610931
# 12    0.640958
# 13    0.563378
# 14    0.621856
# 15    0.572169
# 16    0.596888
# 17    0.591063
# 18    0.558532
# 19    0.494764
# 20    0.532592
# Name: 1, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.579037373184194
# Stdev
# 0.06130506207767524
# Median
# 0.5968877830015069
# IQR
# 0.06332347969518848
# GQI Streamline Count
# 21    0.593448
# 22    0.592647
# 23    0.454313
# 24    0.546210
# 25    0.644447
# 26    0.430576
# 27    0.556105
# 28    0.615597
# 29    0.608029
# 30    0.585431
# 31    0.540963
# 32    0.594848
# 33    0.609132
# 34    0.565851
# 35    0.592926
# 36    0.558713
# 37    0.562922
# 38    0.570820
# 39    0.531897
# 40    0.478631
# 41    0.516424
# Name: 1, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# 0.5595204865223133
# Stdev
# 0.05386433154359136
# Median
# 0.5658512814087836
# IQR
# 0.052484746403602456
# DTI Streamline Count
# 42    0.348021
# 43    0.584208
# 44    0.636889
# 45    0.588736
# 46    0.592056
# 47    0.349727
# 48    0.445306
# 49    0.524400
# 50    0.609821
# 51    0.439780
# 52    0.610463
# 53    0.466257
# 54    0.420167
# 55    0.477103
# 56    0.503793
# 57    0.554985
# 58    0.607062
# 59    0.601742
# 60    0.595028
# 61    0.576561
# 62    0.431221
# Name: 1, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.5220631976882193
# Stdev
# 0.08989469304282798
# Median
# 0.5549849516775256
# IQR
# 0.14972179004910774
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.522063  0.089895  0.554985  0.149722
# 1             GQI Streamline Count  0.522063  0.089895  0.554985  0.149722
# 2             DTI Streamline Count  0.522063  0.089895  0.554985  0.149722
# 0  MSMT CSD SIFT2 Streamline Count  0.559520  0.053864  0.565851  0.052485
# 1             GQI Streamline Count  0.559520  0.053864  0.565851  0.052485
# 2             DTI Streamline Count  0.559520  0.053864  0.565851  0.052485
# 0  MSMT CSD SIFT2 Streamline Count  0.579037  0.061305  0.596888  0.063323
# 1             GQI Streamline Count  0.579037  0.061305  0.596888  0.063323
# 2             DTI Streamline Count  0.579037  0.061305  0.596888  0.063323
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# 21
# 21
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# 21
# 21
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# GQI Streamline Count
# DTI Streamline Count
# 21
# 21
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# DTI Streamline Count
# GQI Streamline Count
# 21
# 21
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          1.095957                      0.860174
# 0                          2.399515                      0.989417
# 0                         -1.095957                      0.139826
# 0                          1.637936                      0.945360
# 0                         -2.399515                      0.010583
# 0                         -1.637936                      0.054640
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          5.877947                      0.999995
# 0                          2.434448                      0.987796
# 0                         -5.877947                      0.000005
# 0                          1.660480                      0.943792
# 0                         -2.434448                      0.012204
# 0                         -1.660480                      0.056208
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    1.179333                0.877384
# 0                    2.407576                0.989619
# 0                   -1.179333                0.122616
# 0                    1.560769                0.936772
# 0                   -2.407576                0.010381
# 0                   -1.560769                0.063228
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    5.926561                0.999996
# 0                    2.404629                0.987003
# 0                   -5.926561                0.000004
# 0                    1.563296                0.933166
# 0                   -2.404629                0.012997
# 0                   -1.563296                0.066834
# Walk Length: 2
# MSMT CSD SIFT2 Streamline Count
# 0     0.617012
# 1     0.614557
# 2     0.467494
# 3     0.532954
# 4     0.670424
# 5     0.422577
# 6     0.612581
# 7     0.623702
# 8     0.636926
# 9     0.633058
# 10    0.582999
# 11    0.620056
# 12    0.642101
# 13    0.564538
# 14    0.620333
# 15    0.563930
# 16    0.596227
# 17    0.594305
# 18    0.558485
# 19    0.498943
# 20    0.530612
# Name: 2, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.5811338895146596
# Stdev
# 0.06201932550736216
# Median
# 0.5962272131722853
# IQR
# 0.06184793028297986
# GQI Streamline Count
# 21    0.576921
# 22    0.586591
# 23    0.475965
# 24    0.546561
# 25    0.651122
# 26    0.400516
# 27    0.570617
# 28    0.603097
# 29    0.609893
# 30    0.589542
# 31    0.543340
# 32    0.588031
# 33    0.616686
# 34    0.542353
# 35    0.594490
# 36    0.549924
# 37    0.572783
# 38    0.580870
# 39    0.517312
# 40    0.490376
# 41    0.513057
# Name: 2, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# 0.5580975348451719
# Stdev
# 0.05593836391000635
# Median
# 0.572783052260828
# IQR
# 0.04718876463271515
# DTI Streamline Count
# 42    0.344107
# 43    0.586181
# 44    0.638788
# 45    0.590751
# 46    0.594068
# 47    0.353721
# 48    0.444867
# 49    0.529039
# 50    0.610798
# 51    0.439705
# 52    0.610569
# 53    0.468671
# 54    0.420352
# 55    0.478363
# 56    0.502654
# 57    0.552896
# 58    0.608378
# 59    0.604283
# 60    0.596712
# 61    0.577469
# 62    0.431208
# Name: 2, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.5230275907451618
# Stdev
# 0.09046118210670091
# Median
# 0.5528956849209352
# IQR
# 0.151845656271338
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.523028  0.090461  0.552896  0.151846
# 1             GQI Streamline Count  0.523028  0.090461  0.552896  0.151846
# 2             DTI Streamline Count  0.523028  0.090461  0.552896  0.151846
# 0  MSMT CSD SIFT2 Streamline Count  0.558098  0.055938  0.572783  0.047189
# 1             GQI Streamline Count  0.558098  0.055938  0.572783  0.047189
# 2             DTI Streamline Count  0.558098  0.055938  0.572783  0.047189
# 0  MSMT CSD SIFT2 Streamline Count  0.581134  0.062019  0.596227  0.061848
# 1             GQI Streamline Count  0.581134  0.062019  0.596227  0.061848
# 2             DTI Streamline Count  0.581134  0.062019  0.596227  0.061848
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# 21
# 21
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# 21
# 21
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# GQI Streamline Count
# DTI Streamline Count
# 21
# 21
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# DTI Streamline Count
# GQI Streamline Count
# 21
# 21
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          1.263967                      0.893221
# 0                          2.427766                      0.990107
# 0                         -1.263967                      0.106779
# 0                          1.511015                      0.930677
# 0                         -2.427766                      0.009893
# 0                         -1.511015                      0.069323
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          6.976981                  9.999995e-01
# 0                          2.457571                  9.883795e-01
# 0                         -6.976981                  4.508419e-07
# 0                          1.614029                  9.389057e-01
# 0                         -2.457571                  1.162049e-02
# 0                         -1.614029                  6.109425e-02
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    1.350392                0.907759
# 0                    2.437079                0.990326
# 0                   -1.350392                0.092241
# 0                    1.433154                0.920208
# 0                   -2.437079                0.009674
# 0                   -1.433154                0.079792
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    7.032218            9.999996e-01
# 0                    2.429590            9.876698e-01
# 0                   -7.032218            4.022443e-07
# 0                    1.508396            9.264556e-01
# 0                   -2.429590            1.233016e-02
# 0                   -1.508396            7.354438e-02
# Walk Length: 3
# MSMT CSD SIFT2 Streamline Count
# 0     0.615350
# 1     0.614690
# 2     0.466934
# 3     0.531838
# 4     0.672857
# 5     0.420820
# 6     0.610835
# 7     0.621599
# 8     0.636822
# 9     0.633447
# 10    0.582680
# 11    0.617017
# 12    0.640759
# 13    0.563713
# 14    0.616363
# 15    0.564228
# 16    0.595061
# 17    0.594919
# 18    0.556019
# 19    0.497899
# 20    0.530805
# Name: 3, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.5802216761222224
# Stdev
# 0.062198465738126985
# Median
# 0.5950611915105162
# IQR
# 0.060997674546437675
# GQI Streamline Count
# 21    0.572273
# 22    0.581666
# 23    0.474110
# 24    0.546766
# 25    0.647898
# 26    0.400269
# 27    0.570050
# 28    0.603625
# 29    0.602232
# 30    0.591887
# 31    0.542956
# 32    0.589442
# 33    0.620774
# 34    0.541741
# 35    0.589063
# 36    0.543611
# 37    0.567519
# 38    0.583848
# 39    0.516469
# 40    0.486983
# 41    0.516831
# Name: 3, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# 0.5566673383813304
# Stdev
# 0.05567598720843295
# Median
# 0.5700503199151365
# IQR
# 0.04770088757691493
# DTI Streamline Count
# 42    0.345842
# 43    0.586836
# 44    0.639932
# 45    0.591329
# 46    0.594747
# 47    0.361428
# 48    0.444471
# 49    0.531468
# 50    0.612226
# 51    0.441973
# 52    0.610029
# 53    0.470050
# 54    0.425268
# 55    0.480394
# 56    0.503509
# 57    0.550948
# 58    0.609486
# 59    0.605087
# 60    0.595970
# 61    0.578307
# 62    0.431972
# Name: 3, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.5243462942421584
# Stdev
# 0.08932394479907158
# Median
# 0.5509479805021928
# IQR
# 0.15149850669241333
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.524346  0.089324  0.550948  0.151499
# 1             GQI Streamline Count  0.524346  0.089324  0.550948  0.151499
# 2             DTI Streamline Count  0.524346  0.089324  0.550948  0.151499
# 0  MSMT CSD SIFT2 Streamline Count  0.556667  0.055676  0.570050  0.047701
# 1             GQI Streamline Count  0.556667  0.055676  0.570050  0.047701
# 2             DTI Streamline Count  0.556667  0.055676  0.570050  0.047701
# 0  MSMT CSD SIFT2 Streamline Count  0.580222  0.062198  0.595061  0.060998
# 1             GQI Streamline Count  0.580222  0.062198  0.595061  0.060998
# 2             DTI Streamline Count  0.580222  0.062198  0.595061  0.060998
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# 21
# 21
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# 21
# 21
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# GQI Streamline Count
# DTI Streamline Count
# 21
# 21
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# DTI Streamline Count
# GQI Streamline Count
# 21
# 21
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          1.293040                      0.898292
# 0                          2.352439                      0.988171
# 0                         -1.293040                      0.101708
# 0                          1.407191                      0.916453
# 0                         -2.352439                      0.011829
# 0                         -1.407191                      0.083547
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          7.059506                  9.999996e-01
# 0                          2.383621                  9.864157e-01
# 0                         -7.059506                  3.802635e-07
# 0                          1.485176                  9.234552e-01
# 0                         -2.383621                  1.358431e-02
# 0                         -1.485176                  7.654477e-02
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    1.381665                0.912628
# 0                    2.357743                0.988317
# 0                   -1.381665                0.087372
# 0                    1.324444                0.903563
# 0                   -2.357743                0.011683
# 0                   -1.324444                0.096437
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    7.064996            9.999996e-01
# 0                    2.355674            9.855964e-01
# 0                   -7.064996            3.759925e-07
# 0                    1.377113            9.081517e-01
# 0                   -2.355674            1.440361e-02
# 0                   -1.377113            9.184828e-02
# Walk Length: 4
# MSMT CSD SIFT2 Streamline Count
# 0     0.613774
# 1     0.615631
# 2     0.467183
# 3     0.532387
# 4     0.674659
# 5     0.421732
# 6     0.610227
# 7     0.621453
# 8     0.637494
# 9     0.633152
# 10    0.579971
# 11    0.614982
# 12    0.641637
# 13    0.562964
# 14    0.612019
# 15    0.565175
# 16    0.591287
# 17    0.595514
# 18    0.556073
# 19    0.496034
# 20    0.527240
# Name: 4, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.5795518535153483
# Stdev
# 0.06225145969648986
# Median
# 0.5955142201461807
# IQR
# 0.05955838199631214
# GQI Streamline Count
# 21    0.573411
# 22    0.578196
# 23    0.476770
# 24    0.547828
# 25    0.651002
# 26    0.390659
# 27    0.568822
# 28    0.597407
# 29    0.600250
# 30    0.593991
# 31    0.547773
# 32    0.588283
# 33    0.620842
# 34    0.540244
# 35    0.592207
# 36    0.541950
# 37    0.567296
# 38    0.587505
# 39    0.513336
# 40    0.478864
# 41    0.512245
# Name: 4, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# 0.5556609544635078
# Stdev
# 0.05773073982898069
# Median
# 0.568821689227937
# IQR
# 0.05196338278170143
# DTI Streamline Count
# 42    0.349301
# 43    0.586149
# 44    0.640525
# 45    0.592244
# 46    0.595575
# 47    0.368937
# 48    0.444839
# 49    0.533965
# 50    0.613366
# 51    0.444932
# 52    0.608407
# 53    0.471722
# 54    0.430805
# 55    0.482885
# 56    0.504201
# 57    0.546979
# 58    0.609809
# 59    0.604869
# 60    0.594814
# 61    0.577823
# 62    0.432556
# Name: 4, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.5254621862181313
# Stdev
# 0.0876567071068773
# Median
# 0.5469793968091865
# IQR
# 0.15064273993212457
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.525462  0.087657  0.546979  0.150643
# 1             GQI Streamline Count  0.525462  0.087657  0.546979  0.150643
# 2             DTI Streamline Count  0.525462  0.087657  0.546979  0.150643
# 0  MSMT CSD SIFT2 Streamline Count  0.555661  0.057731  0.568822  0.051963
# 1             GQI Streamline Count  0.555661  0.057731  0.568822  0.051963
# 2             DTI Streamline Count  0.555661  0.057731  0.568822  0.051963
# 0  MSMT CSD SIFT2 Streamline Count  0.579552  0.062251  0.595514  0.059558
# 1             GQI Streamline Count  0.579552  0.062251  0.595514  0.059558
# 2             DTI Streamline Count  0.579552  0.062251  0.595514  0.059558
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# 21
# 21
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# 21
# 21
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# GQI Streamline Count
# DTI Streamline Count
# 21
# 21
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# DTI Streamline Count
# GQI Streamline Count
# 21
# 21
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          1.289532                      0.897690
# 0                          2.305499                      0.986797
# 0                         -1.289532                      0.102310
# 0                          1.318488                      0.902580
# 0                         -2.305499                      0.013203
# 0                         -1.318488                      0.097420
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          7.119818                  9.999997e-01
# 0                          2.337980                  9.850542e-01
# 0                         -7.119818                  3.359684e-07
# 0                          1.403005                  9.120252e-01
# 0                         -2.337980                  1.494575e-02
# 0                         -1.403005                  8.797476e-02
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    1.370549                0.910921
# 0                    2.309116                0.986908
# 0                   -1.370549                0.089079
# 0                    1.244082                0.889645
# 0                   -2.309116                0.013092
# 0                   -1.244082                0.110355
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    7.187852            9.999997e-01
# 0                    2.311487            9.842072e-01
# 0                   -7.187852            2.923346e-07
# 0                    1.304191            8.965104e-01
# 0                   -2.311487            1.579283e-02
# 0                   -1.304191            1.034896e-01
# Walk Length: 5
# MSMT CSD SIFT2 Streamline Count
# 0     0.615132
# 1     0.615571
# 2     0.468904
# 3     0.530951
# 4     0.673937
# 5     0.420377
# 6     0.611303
# 7     0.620285
# 8     0.639854
# 9     0.634396
# 10    0.577989
# 11    0.613709
# 12    0.642543
# 13    0.564518
# 14    0.607617
# 15    0.564493
# 16    0.588857
# 17    0.596511
# 18    0.558456
# 19    0.494510
# 20    0.522763
# Name: 5, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.5791750682142636
# Stdev
# 0.06260022825263706
# Median
# 0.5965113397689128
# IQR
# 0.05711499259174846
# GQI Streamline Count
# 21    0.568425
# 22    0.577067
# 23    0.483239
# 24    0.547968
# 25    0.651896
# 26    0.387437
# 27    0.567386
# 28    0.592908
# 29    0.598989
# 30    0.593646
# 31    0.551701
# 32    0.588458
# 33    0.621628
# 34    0.541763
# 35    0.584072
# 36    0.540647
# 37    0.572500
# 38    0.588391
# 39    0.513318
# 40    0.476156
# 41    0.509625
# Name: 5, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# 0.5551056150921118
# Stdev
# 0.05769807890216146
# Median
# 0.5684252433069261
# IQR
# 0.04781096090438841
# DTI Streamline Count
# 42    0.354851
# 43    0.586276
# 44    0.640856
# 45    0.590977
# 46    0.595804
# 47    0.382434
# 48    0.446428
# 49    0.535687
# 50    0.614094
# 51    0.450718
# 52    0.609797
# 53    0.471916
# 54    0.439975
# 55    0.484583
# 56    0.505689
# 57    0.543306
# 58    0.609863
# 59    0.603394
# 60    0.594496
# 61    0.578259
# 62    0.432355
# Name: 5, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.5272266586807195
# Stdev
# 0.08503955247007011
# Median
# 0.5433062425199608
# IQR
# 0.14508640098181547
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.527227  0.085040  0.543306  0.145086
# 1             GQI Streamline Count  0.527227  0.085040  0.543306  0.145086
# 2             DTI Streamline Count  0.527227  0.085040  0.543306  0.145086
# 0  MSMT CSD SIFT2 Streamline Count  0.555106  0.057698  0.568425  0.047811
# 1             GQI Streamline Count  0.555106  0.057698  0.568425  0.047811
# 2             DTI Streamline Count  0.555106  0.057698  0.568425  0.047811
# 0  MSMT CSD SIFT2 Streamline Count  0.579175  0.062600  0.596511  0.057115
# 1             GQI Streamline Count  0.579175  0.062600  0.596511  0.057115
# 2             DTI Streamline Count  0.579175  0.062600  0.596511  0.057115
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# 21
# 21
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# 21
# 21
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# GQI Streamline Count
# DTI Streamline Count
# 21
# 21
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# 21
# 21
# DTI Streamline Count
# GQI Streamline Count
# 21
# 21
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          1.295600                      0.898730
# 0                          2.254418                      0.985142
# 0                         -1.295600                      0.101270
# 0                          1.243191                      0.889482
# 0                         -2.254418                      0.014858
# 0                         -1.243191                      0.110518
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          6.443815                      0.999999
# 0                          2.281523                      0.983196
# 0                         -6.443815                      0.000001
# 0                          1.340054                      0.902373
# 0                         -2.281523                      0.016804
# 0                         -1.340054                      0.097627
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    1.379124                0.912240
# 0                    2.259963                0.985330
# 0                   -1.379124                0.087760
# 0                    1.171599                0.875855
# 0                   -2.259963                0.014670
# 0                   -1.171599                0.124145
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    6.534946                0.999999
# 0                    2.259683                0.982422
# 0                   -6.534946                0.000001
# 0                    1.245439                0.886318
# 0                   -2.259683                0.017578
# 0                   -1.245439                0.113682
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch42.csv
# volume_weighted_all_batch42
# Walk Length: 1
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# 0     0.612783
# 1     0.559119
# 2     0.543670
# 3     0.623039
# 4     0.600906
# 5     0.391949
# 6     0.452126
# 7     0.611903
# 8     0.458294
# 9     0.658363
# 10    0.520671
# 11    0.508480
# 12    0.648865
# 13    0.528669
# 14    0.504706
# 15    0.548747
# 16    0.519922
# 17    0.578358
# 18    0.557154
# 19    0.516125
# 20    0.418417
# Name: 1, dtype: float64
# Statistics for MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# Mean
# 0.5410601856985091
# Stdev
# 0.07209176992994716
# Median
# 0.5436695201608778
# IQR
# 0.09242588618233716
# GQI Node Volume Weighted Streamline Count
# 21    0.568285
# 22    0.557638
# 23    0.550931
# 24    0.628302
# 25    0.609260
# 26    0.405632
# 27    0.438219
# 28    0.611012
# 29    0.440533
# 30    0.650880
# 31    0.537374
# 32    0.498267
# 33    0.601498
# 34    0.507858
# 35    0.502950
# 36    0.538403
# 37    0.518695
# 38    0.562065
# 39    0.536364
# 40    0.510538
# 41    0.407227
# Name: 1, dtype: float64
# Statistics for GQI Node Volume Weighted Streamline Count
# Mean
# 0.5324728086917122
# Stdev
# 0.06916268160527952
# Median
# 0.5373739127930435
# IQR
# 0.06533592835346802
# DTI Node Volume Weighted Streamline Count
# 42    0.403009
# 43    0.475713
# 44    0.481194
# 45    0.526301
# 46    0.351125
# 47    0.463549
# 48    0.477622
# 49    0.370337
# 50    0.480101
# 51    0.493036
# 52    0.510928
# 53    0.397637
# 54    0.506310
# 55    0.458304
# 56    0.529761
# 57    0.538205
# 58    0.376534
# 59    0.492659
# 60    0.520366
# 61    0.462763
# 62    0.579483
# Name: 1, dtype: float64
# Statistics for DTI Node Volume Weighted Streamline Count
# Mean
# 0.47118751866415165
# Stdev
# 0.06041409152429231
# Median
# 0.4801011915715776
# IQR
# 0.05262405895885969
#                                                Recon      Mean     Stdev  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...  0.471188  0.060414
# 1          GQI Node Volume Weighted Streamline Count  0.471188  0.060414
# 2          DTI Node Volume Weighted Streamline Count  0.471188  0.060414
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...  0.532473  0.069163
# 1          GQI Node Volume Weighted Streamline Count  0.532473  0.069163
# 2          DTI Node Volume Weighted Streamline Count  0.532473  0.069163
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...  0.541060  0.072092
# 1          GQI Node Volume Weighted Streamline Count  0.541060  0.072092
# 2          DTI Node Volume Weighted Streamline Count  0.541060  0.072092
#
#      Median       IQR
# 0  0.480101  0.052624
# 1  0.480101  0.052624
# 2  0.480101  0.052624
# 0  0.537374  0.065336
# 1  0.537374  0.065336
# 2  0.537374  0.065336
# 0  0.543670  0.092426
# 1  0.543670  0.092426
# 2  0.543670  0.092426
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# GQI Node Volume Weighted Streamline Count
# 21
# 21
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# DTI Node Volume Weighted Streamline Count
# 21
# 21
# GQI Node Volume Weighted Streamline Count
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# 21
# 21
# GQI Node Volume Weighted Streamline Count
# DTI Node Volume Weighted Streamline Count
# 21
# 21
# DTI Node Volume Weighted Streamline Count
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# 21
# 21
# DTI Node Volume Weighted Streamline Count
# GQI Node Volume Weighted Streamline Count
# 21
# 21
# T-test ind results
#                                              Recon 1  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
#
#                                              Recon 2  \
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          0.393903                      0.652128
# 0                          3.404214                      0.999240
# 0                         -0.393903                      0.347872
# 0                          3.058202                      0.998020
# 0                         -3.404214                      0.000760
# 0                         -3.058202                      0.001980
# T-test rel results
#                                              Recon 1  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
#
#                                              Recon 2  \
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          2.403280                      0.986966
# 0                          3.106604                      0.997220
# 0                         -2.403280                      0.013034
# 0                          2.762782                      0.993998
# 0                         -3.106604                      0.002780
# 0                         -2.762782                      0.006002
# T-test ind z-score results
#                                              Recon 1  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
#
#                                              Recon 2  \
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    0.414101                0.659494
# 0                    3.470190                0.999370
# 0                   -0.414101                0.340506
# 0                    3.120427                0.998327
# 0                   -3.470190                0.000630
# 0                   -3.120427                0.001673
# T-test rel z-score results
#                                              Recon 1  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
#
#                                              Recon 2  \
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    2.335398                0.984974
# 0                    3.184278                0.997670
# 0                   -2.335398                0.015026
# 0                    2.832132                0.994851
# 0                   -3.184278                0.002330
# 0                   -2.832132                0.005149
# Walk Length: 2
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# 0     0.619510
# 1     0.554492
# 2     0.543896
# 3     0.621203
# 4     0.602331
# 5     0.393325
# 6     0.453914
# 7     0.617500
# 8     0.456493
# 9     0.657849
# 10    0.513567
# 11    0.517198
# 12    0.646547
# 13    0.532370
# 14    0.499977
# 15    0.555539
# 16    0.520248
# 17    0.574770
# 18    0.560601
# 19    0.519365
# 20    0.416990
# Name: 2, dtype: float64
# Statistics for MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# Mean
# 0.5417944957829308
# Stdev
# 0.07238922438364644
# Median
# 0.5438959914925063
# IQR
# 0.08876360146283502
# GQI Node Volume Weighted Streamline Count
# 21    0.580092
# 22    0.555900
# 23    0.548380
# 24    0.638923
# 25    0.615065
# 26    0.426973
# 27    0.445897
# 28    0.616027
# 29    0.451528
# 30    0.649153
# 31    0.536415
# 32    0.479183
# 33    0.610661
# 34    0.526871
# 35    0.495339
# 36    0.534386
# 37    0.509251
# 38    0.570544
# 39    0.537199
# 40    0.518957
# 41    0.412922
# Name: 2, dtype: float64
# Statistics for GQI Node Volume Weighted Streamline Count
# Mean
# 0.5361745182699167
# Stdev
# 0.06840199084081304
# Median
# 0.5364145103289482
# IQR
# 0.08475310682133935
# DTI Node Volume Weighted Streamline Count
# 42    0.489326
# 43    0.551146
# 44    0.564286
# 45    0.572169
# 46    0.408881
# 47    0.549095
# 48    0.519798
# 49    0.396910
# 50    0.532052
# 51    0.548833
# 52    0.554068
# 53    0.437246
# 54    0.574382
# 55    0.513599
# 56    0.573725
# 57    0.592186
# 58    0.419548
# 59    0.560433
# 60    0.600446
# 61    0.557944
# 62    0.630110
# Name: 2, dtype: float64
# Statistics for DTI Node Volume Weighted Streamline Count
# Mean
# 0.5307704862629787
# Stdev
# 0.06494040984507625
# Median
# 0.5511458615748258
# IQR
# 0.058569832163211544
#                                                Recon      Mean     Stdev  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...  0.530770  0.064940
# 1          GQI Node Volume Weighted Streamline Count  0.530770  0.064940
# 2          DTI Node Volume Weighted Streamline Count  0.530770  0.064940
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...  0.536175  0.068402
# 1          GQI Node Volume Weighted Streamline Count  0.536175  0.068402
# 2          DTI Node Volume Weighted Streamline Count  0.536175  0.068402
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...  0.541794  0.072389
# 1          GQI Node Volume Weighted Streamline Count  0.541794  0.072389
# 2          DTI Node Volume Weighted Streamline Count  0.541794  0.072389
#
#      Median       IQR
# 0  0.551146  0.058570
# 1  0.551146  0.058570
# 2  0.551146  0.058570
# 0  0.536415  0.084753
# 1  0.536415  0.084753
# 2  0.536415  0.084753
# 0  0.543896  0.088764
# 1  0.543896  0.088764
# 2  0.543896  0.088764
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# GQI Node Volume Weighted Streamline Count
# 21
# 21
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# DTI Node Volume Weighted Streamline Count
# 21
# 21
# GQI Node Volume Weighted Streamline Count
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# 21
# 21
# GQI Node Volume Weighted Streamline Count
# DTI Node Volume Weighted Streamline Count
# 21
# 21
# DTI Node Volume Weighted Streamline Count
# MSMT CSD SIFT2 Node Volume Weighted Streamline Count
# 21
# 21
# DTI Node Volume Weighted Streamline Count
# GQI Node Volume Weighted Streamline Count
# 21
# 21
# T-test ind results
#                                              Recon 1  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
#
#                                              Recon 2  \
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          0.258589                      0.601361
# 0                          0.519472                      0.696853
# 0                         -0.258589                      0.398639
# 0                          0.262560                      0.602881
# 0                         -0.519472                      0.303147
# 0                         -0.262560                      0.397119
# T-test rel results
#                                              Recon 1  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
#
#                                              Recon 2  \
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          1.362579                      0.905919
# 0                          0.472397                      0.679121
# 0                         -1.362579                      0.094081
# 0                          0.239579                      0.593452
# 0                         -0.472397                      0.320879
# 0                         -0.239579                      0.406548
# T-test ind z-score results
#                                              Recon 1  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
#
#                                              Recon 2  \
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          DTI Node Volume Weighted Streamline Count
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                    0.278017                0.608784
# 0                    0.576795                0.716345
# 0                   -0.278017                0.391216
# 0                    0.296123                0.615666
# 0                   -0.576795                0.283655
# 0                   -0.296123                0.384334
# T-test rel z-score results
#                                              Recon 1  \
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0  MSMT CSD SIFT2 Node Volume Weighted Streamline...
# 0          GQI Node Volume Weighted Streamline Count
# 0          GQI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
# 0          DTI Node Volume Weighted Streamline Count
#
# ...
# 34    0.606450
# 35    0.428168
# 36    0.507923
# 37    0.532011
# 38    0.560630
# 39    0.527681
# 40    0.582564
# 41    0.524146
# Name: 3, dtype: float64
# Statistics for GQI Mean Length
# Mean
# 0.5012504121810339
# Stdev
# 0.07607669680235152
# Median
# 0.5117285294508674
# IQR
# 0.11376809459625808
# DTI Mean Length
# 42    0.595695
# 43    0.607091
# 44    0.590166
# 45    0.547473
# 46    0.605353
# 47    0.663324
# 48    0.532649
# 49    0.398416
# 50    0.618883
# 51    0.516036
# 52    0.582595
# 53    0.604404
# 54    0.528309
# 55    0.461828
# 56    0.447349
# 57    0.567443
# 58    0.492201
# 59    0.633851
# 60    0.471228
# 61    0.541127
# 62    0.572923
# Name: 3, dtype: float64
# Statistics for DTI Mean Length
# Mean
# 0.5513496624076999
# Stdev
# 0.0679344122513991
# Median
# 0.5674426147679943
# IQR
# 0.0883680658927386
#                   Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD Mean Length  0.551350  0.067934  0.567443  0.088368
# 1       GQI Mean Length  0.551350  0.067934  0.567443  0.088368
# 2       DTI Mean Length  0.551350  0.067934  0.567443  0.088368
# 0  MSMT CSD Mean Length  0.501250  0.076077  0.511729  0.113768
# 1       GQI Mean Length  0.501250  0.076077  0.511729  0.113768
# 2       DTI Mean Length  0.501250  0.076077  0.511729  0.113768
# 0  MSMT CSD Mean Length  0.410463  0.084514  0.399856  0.155877
# 1       GQI Mean Length  0.410463  0.084514  0.399856  0.155877
# 2       DTI Mean Length  0.410463  0.084514  0.399856  0.155877
# MSMT CSD Mean Length
# GQI Mean Length
# 21
# 21
# MSMT CSD Mean Length
# DTI Mean Length
# 21
# 21
# GQI Mean Length
# MSMT CSD Mean Length
# 21
# 21
# GQI Mean Length
# DTI Mean Length
# 21
# 21
# DTI Mean Length
# MSMT CSD Mean Length
# 21
# 21
# DTI Mean Length
# GQI Mean Length
# 21
# 21
# T-test ind results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -3.658744                  3.658176e-04
# 0                         -5.954138                  2.741520e-07
# 0                          3.658744                  9.996342e-01
# 0                         -2.250955                  1.497647e-02
# 0                          5.954138                  9.999997e-01
# 0                          2.250955                  9.850235e-01
# T-test rel results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                        -10.671643                  5.244565e-10
# 0                         -5.579815                  9.203335e-06
# 0                         10.671643                  1.000000e+00
# 0                         -2.146544                  2.213867e-02
# 0                          5.579815                  9.999908e-01
# 0                          2.146544                  9.778613e-01
# T-test ind z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -3.636185
# 0  MSMT CSD Mean Length       DTI Mean Length                   -5.986281
# 0       GQI Mean Length  MSMT CSD Mean Length                    3.636185
# 0       GQI Mean Length       DTI Mean Length                   -2.254649
# 0       DTI Mean Length  MSMT CSD Mean Length                    5.986281
# 0       DTI Mean Length       GQI Mean Length                    2.254649
#
#    p-value z-score t-test
# 0            3.906628e-04
# 0            2.470561e-07
# 0            9.996093e-01
# 0            1.484993e-02
# 0            9.999998e-01
# 0            9.851501e-01
# T-test rel z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                  -11.344178
# 0  MSMT CSD Mean Length       DTI Mean Length                   -5.630755
# 0       GQI Mean Length  MSMT CSD Mean Length                   11.344178
# 0       GQI Mean Length       DTI Mean Length                   -2.164033
# 0       DTI Mean Length  MSMT CSD Mean Length                    5.630755
# 0       DTI Mean Length       GQI Mean Length                    2.164033
#
#    p-value z-score t-test
# 0            1.823006e-10
# 0            8.210695e-06
# 0            1.000000e+00
# 0            2.136973e-02
# 0            9.999918e-01
# 0            9.786303e-01
# Walk Length: 4
# MSMT CSD Mean Length
# 0     0.526386
# 1     0.356133
# 2     0.313334
# 3     0.484107
# 4     0.359913
# 5     0.306155
# 6     0.426827
# 7     0.466448
# 8     0.594961
# 9     0.413838
# 10    0.388209
# 11    0.428944
# 12    0.347870
# 13    0.542232
# 14    0.337498
# 15    0.456119
# 16    0.502641
# 17    0.509465
# 18    0.481774
# 19    0.549944
# 20    0.423328
# Name: 4, dtype: float64
# Statistics for MSMT CSD Mean Length
# Mean
# 0.4388632233236013
# Stdev
# 0.08298435830617239
# Median
# 0.4289440498371263
# IQR
# 0.14272807341092408
# GQI Mean Length
# 21    0.567888
# 22    0.443385
# 23    0.395506
# 24    0.547438
# 25    0.473844
# 26    0.389012
# 27    0.465391
# 28    0.510006
# 29    0.640246
# 30    0.486990
# 31    0.364408
# 32    0.557713
# 33    0.425130
# 34    0.609983
# 35    0.433789
# 36    0.506474
# 37    0.528337
# 38    0.562786
# 39    0.526844
# 40    0.582169
# 41    0.528204
# Name: 4, dtype: float64
# Statistics for GQI Mean Length
# Mean
# 0.502168639495237
# Stdev
# 0.07479280479799169
# Median
# 0.5100056199884522
# IQR
# 0.11432798446265152
# DTI Mean Length
# 42    0.593937
# 43    0.613525
# 44    0.589649
# 45    0.544885
# 46    0.607557
# 47    0.661832
# 48    0.531972
# 49    0.396810
# 50    0.618012
# 51    0.516239
# 52    0.581460
# 53    0.604094
# 54    0.527716
# 55    0.459631
# 56    0.449323
# 57    0.570103
# 58    0.494353
# 59    0.637517
# 60    0.476537
# 61    0.537478
# 62    0.569633
# Name: 4, dtype: float64
# Statistics for DTI Mean Length
# Mean
# 0.5515363147711643
# Stdev
# 0.06808279227945802
# Median
# 0.5696329225980308
# IQR
# 0.0878548836730133
#                   Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD Mean Length  0.551536  0.068083  0.569633  0.087855
# 1       GQI Mean Length  0.551536  0.068083  0.569633  0.087855
# 2       DTI Mean Length  0.551536  0.068083  0.569633  0.087855
# 0  MSMT CSD Mean Length  0.502169  0.074793  0.510006  0.114328
# 1       GQI Mean Length  0.502169  0.074793  0.510006  0.114328
# 2       DTI Mean Length  0.502169  0.074793  0.510006  0.114328
# 0  MSMT CSD Mean Length  0.438863  0.082984  0.428944  0.142728
# 1       GQI Mean Length  0.438863  0.082984  0.428944  0.142728
# 2       DTI Mean Length  0.438863  0.082984  0.428944  0.142728
# MSMT CSD Mean Length
# GQI Mean Length
# 21
# 21
# MSMT CSD Mean Length
# DTI Mean Length
# 21
# 21
# GQI Mean Length
# MSMT CSD Mean Length
# 21
# 21
# GQI Mean Length
# DTI Mean Length
# 21
# 21
# DTI Mean Length
# MSMT CSD Mean Length
# 21
# 21
# DTI Mean Length
# GQI Mean Length
# 21
# 21
# T-test ind results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -2.596790                      0.006551
# 0                         -4.810300                      0.000011
# 0                          2.596790                      0.993449
# 0                         -2.236819                      0.015470
# 0                          4.810300                      0.999989
# 0                          2.236819                      0.984530
# T-test rel results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -8.434863                  2.548263e-08
# 0                         -4.445898                  1.240865e-04
# 0                          8.434863                  1.000000e+00
# 0                         -2.124839                  2.312781e-02
# 0                          4.445898                  9.998759e-01
# 0                          2.124839                  9.768722e-01
# T-test ind z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -2.581900
# 0  MSMT CSD Mean Length       DTI Mean Length                   -4.839183
# 0       GQI Mean Length  MSMT CSD Mean Length                    2.581900
# 0       GQI Mean Length       DTI Mean Length                   -2.245851
# 0       DTI Mean Length  MSMT CSD Mean Length                    4.839183
# 0       DTI Mean Length       GQI Mean Length                    2.245851
#
#    p-value z-score t-test
# 0                0.006797
# 0                0.000010
# 0                0.993203
# 0                0.015153
# 0                0.999990
# 0                0.984847
# T-test rel z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -8.960543
# 0  MSMT CSD Mean Length       DTI Mean Length                   -4.486344
# 0       GQI Mean Length  MSMT CSD Mean Length                    8.960543
# 0       GQI Mean Length       DTI Mean Length                   -2.146508
# 0       DTI Mean Length  MSMT CSD Mean Length                    4.486344
# 0       DTI Mean Length       GQI Mean Length                    2.146508
#
#    p-value z-score t-test
# 0            9.685778e-09
# 0            1.129221e-04
# 0            1.000000e+00
# 0            2.214028e-02
# 0            9.998871e-01
# 0            9.778597e-01
# Walk Length: 5
# MSMT CSD Mean Length
# 0     0.545435
# 1     0.372770
# 2     0.331319
# 3     0.502671
# 4     0.379473
# 5     0.326735
# 6     0.445621
# 7     0.481849
# 8     0.606025
# 9     0.435513
# 10    0.395429
# 11    0.456648
# 12    0.364394
# 13    0.570104
# 14    0.368927
# 15    0.471188
# 16    0.512908
# 17    0.534546
# 18    0.508169
# 19    0.562975
# 20    0.442846
# Name: 5, dtype: float64
# Statistics for MSMT CSD Mean Length
# Mean
# 0.45788308267095296
# Stdev
# 0.082305313480046
# Median
# 0.4566477038260403
# IQR
# 0.13343521662196456
# GQI Mean Length
# 21    0.559726
# 22    0.439755
# 23    0.394826
# 24    0.544946
# 25    0.475099
# 26    0.385512
# 27    0.469152
# 28    0.512567
# 29    0.638938
# 30    0.488547
# 31    0.359318
# 32    0.551724
# 33    0.423159
# 34    0.611885
# 35    0.437062
# 36    0.504260
# 37    0.528474
# 38    0.559262
# 39    0.524285
# 40    0.577757
# 41    0.524526
# Name: 5, dtype: float64
# Statistics for GQI Mean Length
# Mean
# 0.5005133808247566
# Stdev
# 0.07448963285172117
# Median
# 0.5125668034987251
# IQR
# 0.11196859488167604
# DTI Mean Length
# 42    0.592581
# 43    0.619704
# 44    0.591799
# 45    0.548366
# 46    0.609316
# 47    0.661032
# 48    0.533637
# 49    0.398748
# 50    0.616487
# 51    0.517479
# 52    0.582915
# 53    0.603250
# 54    0.531162
# 55    0.455499
# 56    0.452328
# 57    0.570587
# 58    0.496378
# 59    0.643344
# 60    0.475910
# 61    0.538274
# 62    0.568797
# Name: 5, dtype: float64
# Statistics for DTI Mean Length
# Mean
# 0.552742492306932
# Stdev
# 0.06836283187960047
# Median
# 0.5687972631471417
# IQR
# 0.08577101416543453
#                   Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD Mean Length  0.552742  0.068363  0.568797  0.085771
# 1       GQI Mean Length  0.552742  0.068363  0.568797  0.085771
# 2       DTI Mean Length  0.552742  0.068363  0.568797  0.085771
# 0  MSMT CSD Mean Length  0.500513  0.074490  0.512567  0.111969
# 1       GQI Mean Length  0.500513  0.074490  0.512567  0.111969
# 2       DTI Mean Length  0.500513  0.074490  0.512567  0.111969
# 0  MSMT CSD Mean Length  0.457883  0.082305  0.456648  0.133435
# 1       GQI Mean Length  0.457883  0.082305  0.456648  0.133435
# 2       DTI Mean Length  0.457883  0.082305  0.456648  0.133435
# MSMT CSD Mean Length
# GQI Mean Length
# 21
# 21
# MSMT CSD Mean Length
# DTI Mean Length
# 21
# 21
# GQI Mean Length
# MSMT CSD Mean Length
# 21
# 21
# GQI Mean Length
# DTI Mean Length
# 21
# 21
# DTI Mean Length
# MSMT CSD Mean Length
# 21
# 21
# DTI Mean Length
# GQI Mean Length
# 21
# 21
# T-test ind results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -1.759836                      0.043041
# 0                         -4.062862                      0.000110
# 0                          1.759836                      0.956959
# 0                         -2.367285                      0.011423
# 0                          4.062862                      0.999890
# 0                          2.367285                      0.988577
# T-test rel results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -6.237061                      0.000002
# 0                         -3.711971                      0.000689
# 0                          6.237061                      0.999998
# 0                         -2.209300                      0.019491
# 0                          3.711971                      0.999311
# 0                          2.209300                      0.980509
# T-test ind z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -1.741501
# 0  MSMT CSD Mean Length       DTI Mean Length                   -4.081077
# 0       GQI Mean Length  MSMT CSD Mean Length                    1.741501
# 0       GQI Mean Length       DTI Mean Length                   -2.382320
# 0       DTI Mean Length  MSMT CSD Mean Length                    4.081077
# 0       DTI Mean Length       GQI Mean Length                    2.382320
#
#    p-value z-score t-test
# 0                0.044641
# 0                0.000104
# 0                0.955359
# 0                0.011024
# 0                0.999896
# 0                0.988976
# T-test rel z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -6.600706
# 0  MSMT CSD Mean Length       DTI Mean Length                   -3.742828
# 0       GQI Mean Length  MSMT CSD Mean Length                    6.600706
# 0       GQI Mean Length       DTI Mean Length                   -2.236310
# 0       DTI Mean Length  MSMT CSD Mean Length                    3.742828
# 0       DTI Mean Length       GQI Mean Length                    2.236310
#
#    p-value z-score t-test
# 0            9.911920e-07
# 0            6.413156e-04
# 0            9.999990e-01
# 0            1.844326e-02
# 0            9.993587e-01
# 0            9.815567e-01

# %% [markdown]
# Make Box Plots

# %%
# Read data
main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/'
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/'
file_list = Path(main_path).glob('*batch??.csv')
for file in file_list:
    print(file)
    df = pd.read_csv(file)
    print(file.stem)
    # melt data for boxplot
    dd=pd.melt(df,id_vars=['Recon'],value_vars=['1','2','3','4','5'],var_name='Walk Length')
    # seaborn boxplot with hue based on recon method
    sns.boxplot(x='Walk Length',y='value',data=dd,hue='Recon')
    # plt.show()
    plt.ylabel('Pearson Score')
    # save figure
    plt.savefig(main_path+'/figures/'+file.stem+'_box_plot.png')
    plt.close()
# Out:
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch41.csv
# count_all_batch41
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch42.csv
# volume_weighted_all_batch42
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch46.csv
# count_all_batch46
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch46.csv
# volume_weighted_all_batch46
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch32.csv
# count_all_batch32
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch42.csv
# mean_length_all_batch42
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch31.csv
# volume_weighted_all_batch31
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch46.csv
# mean_length_all_batch46
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch33.csv
# count_all_batch33
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch47.csv
# mean_length_all_batch47
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch47.csv
# volume_weighted_all_batch47
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch37.csv
# volume_weighted_all_batch37
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch33.csv
# volume_weighted_all_batch33
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch34.csv
# mean_length_all_batch34
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch37.csv
# count_all_batch37
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch40.csv
# mean_length_all_batch40
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch45.csv
# volume_weighted_all_batch45
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch36.csv
# mean_length_all_batch36
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch30.csv
# count_all_batch30
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch40.csv
# volume_weighted_all_batch40
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch37.csv
# mean_length_all_batch37
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch32.csv
# volume_weighted_all_batch32
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch33.csv
# mean_length_all_batch33
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch35.csv
# count_all_batch35
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch45.csv
# count_all_batch45
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch30.csv
# volume_weighted_all_batch30
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch41.csv
# volume_weighted_all_batch41
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch48.csv
# volume_weighted_all_batch48
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch34.csv
# count_all_batch34
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch41.csv
# mean_length_all_batch41
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch31.csv
# count_all_batch31
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch43.csv
# volume_weighted_all_batch43
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch48.csv
# count_all_batch48
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch44.csv
# count_all_batch44
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch44.csv
# volume_weighted_all_batch44
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch43.csv
# count_all_batch43
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch44.csv
# mean_length_all_batch44
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch30.csv
# mean_length_all_batch30
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch47.csv
# count_all_batch47
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch38.csv
# count_all_batch38
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch35.csv
# volume_weighted_all_batch35
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch31.csv
# mean_length_all_batch31
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch40.csv
# count_all_batch40
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch45.csv
# mean_length_all_batch45
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch36.csv
# volume_weighted_all_batch36
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch34.csv
# volume_weighted_all_batch34
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch32.csv
# mean_length_all_batch32
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch42.csv
# count_all_batch42
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/count_all_batch36.csv
# count_all_batch36
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch43.csv
# mean_length_all_batch43
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/volume_weighted_all_batch38.csv
# volume_weighted_all_batch38
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch38.csv
# mean_length_all_batch38
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch35.csv
# mean_length_all_batch35
# /home/paul/thesis/dev/SAY_sf_prediction_v2/dataset/mean_length_all_batch48.csv
# mean_length_all_batch48
