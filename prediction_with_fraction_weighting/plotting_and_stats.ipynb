# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import scipy.stats as stats
from scipy.stats import ttest_rel

# %% [markdown]
# Read in files and perform statistical tests of independence for Pearson scores at each walk length

# %%
# Read data
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/'
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/'
file_list = Path(main_path).glob('*batch??.csv')
for file in file_list:
    print(file)
    df = pd.read_csv(file)
    # ,ave to a copy of df, then perform Fisher's r to z transformation on Pearson scores
    df_z = df.copy()
    for i in range(1, 6):
        df_z[str(i)] = np.arctanh(df_z[str(i)])
    # print(df_z)
    print(file.stem)
    # compare difference in score between Recon methods for each walk length column
    for i in range(1, 6):
        print('Walk Length: '+str(i))
        # get unique values of Recon column
        recon_list = df['Recon'].unique()
        df_stats_all = pd.DataFrame()
        df_stats = pd.DataFrame()
        # loop through each unique value of Recon column
        for recon in recon_list:
            print(recon)
            print(df[df['Recon'] == str(recon)][str(i)])
            print('Statistics for '+str(recon))
            print('Mean')
            print(df[df['Recon'] == str(recon)][str(i)].mean())
            print('Stdev')
            print(df[df['Recon'] == str(recon)][str(i)].std())
            print('Median')
            print(df[df['Recon'] == str(recon)][str(i)].median())
            print('IQR')
            print(df[df['Recon'] == str(recon)][str(i)].quantile(
                q=0.75)-df[df['Recon'] == str(recon)][str(i)].quantile(q=0.25))
            # combine statistics from each Recon method into dataframe
            df_stats = pd.DataFrame({'Recon': recon_list, 'Mean': df[df['Recon'] == str(recon)][str(i)].mean(), 'Stdev': df[df['Recon'] == str(recon)][str(i)].std(
            ), 'Median': df[df['Recon'] == str(recon)][str(i)].median(), 'IQR': df[df['Recon'] == str(recon)][str(i)].quantile(q=0.75)-df[df['Recon'] == str(recon)][str(i)].quantile(q=0.25)})
            # combine df_stats from each Recon method into dataframe
            df_stats_all = pd.concat([df_stats, df_stats_all], axis=0)
        print(df_stats_all)
        # save dataframe to csv
        df_stats_all.to_csv(main_path+'/'+file.stem +
                            '_walk_length_'+str(i)+'_stats.csv', index=False)
        # calculate p-value for difference in score between Recon methods in recon_list, with comparisons between each pair of Recon methods, save all statistics and p-values to csv
        df_ttest_results = pd.DataFrame()
        df_ttest_rel_results = pd.DataFrame()
        df_z_ttest_results = pd.DataFrame()
        df_z_ttest_rel_results = pd.DataFrame()
        for recon in recon_list:
            for recon2 in recon_list:
                if recon != recon2:
                    print(recon)
                    print(recon2)
                    # calculate t-test on Pearson scores, get t-statistic and p-value
                    ttest_pearson_score = stats.ttest_ind(df[df['Recon'] == str(
                        recon)][str(i)], df[df['Recon'] == str(recon2)][str(i)], alternative='less')
                    ttest_rel_pearson_score = ttest_rel(df[df['Recon'] == str(
                        recon)][str(i)], df[df['Recon'] == str(recon2)][str(i)], alternative='less')
                    ttest_z_score = stats.ttest_ind(df_z[df_z['Recon'] == str(
                        recon)][str(i)], df_z[df_z['Recon'] == str(recon2)][str(i)], alternative='less')
                    ttest_rel_z_score = ttest_rel(df_z[df_z['Recon'] == str(
                        recon)][str(i)], df_z[df_z['Recon'] == str(recon2)][str(i)], alternative='less')
                    # combine t-test results into dataframe
                    df_ttest_results = pd.concat([df_ttest_results, pd.DataFrame({'Recon 1': recon, 'Recon 2': recon2, 'T-statistic Pearson Score t-test': ttest_pearson_score[0],
                                                 'p-value Pearson Score t-test':ttest_pearson_score[1]}, index=[0])], axis=0)  # ,'T-statistic z-score':ttest_z_score[0],'p-value z-score':ttest_z_score[1]
                    df_ttest_rel_results = pd.concat([df_ttest_rel_results, pd.DataFrame({'Recon 1': recon, 'Recon 2': recon2, 'T-statistic Pearson Score t-test': ttest_rel_pearson_score[0],
                                                    'p-value Pearson Score t-test':ttest_rel_pearson_score[1]}, index=[0])], axis=0)  # ,'T-statistic z-score':ttest_z_score[0],'p-value z-score':ttest_z_score[1]
                    df_z_ttest_rel_results = pd.concat([df_z_ttest_rel_results, pd.DataFrame({'Recon 1': recon, 'Recon 2': recon2, 'T-statistic z-score t-test': ttest_rel_z_score[0],
                                                    'p-value z-score t-test':ttest_rel_z_score[1]}, index=[0])], axis=0)  # ,'T-statistic z-score':ttest_z_score[0],'p-value z-score':ttest_z_score[1]
                    df_z_ttest_results = pd.concat([df_z_ttest_results, pd.DataFrame({'Recon 1': recon, 'Recon 2': recon2, 'T-statistic z-score t-test': ttest_z_score[0],
                                                    'p-value z-score t-test':ttest_z_score[1]}, index=[0])], axis=0)  # ,'T-statistic z-score':ttest_z_score[0],'p-value z-score':ttest_z_score[1]
        print('T-test ind results')
        print(df_ttest_results)
        print('T-test rel results')
        print(df_ttest_rel_results)
        print('T-test ind z-score results')
        print(df_z_ttest_results)
        print('T-test rel z-score results')
        print(df_z_ttest_rel_results)

        # save dataframe to csv
        df_ttest_results.to_csv(
            main_path+'/'+file.stem+'_walk_length_'+str(i)+'_ttest_results.csv', index=False)
        df_ttest_rel_results.to_csv(
            main_path+'/'+file.stem+'_walk_length_'+str(i)+'_ttest_rel_results.csv', index=False)
        df_z_ttest_results.to_csv(
            main_path+'/'+file.stem+'_walk_length_'+str(i)+'_z_score_ttest_results.csv', index=False)
        df_z_ttest_rel_results.to_csv(
            main_path+'/'+file.stem+'_walk_length_'+str(i)+'_z_score_ttest_rel_results.csv', index=False)
        # # calculate non-parametric statistics for difference in score between Recon methods in recon_list, with comparisons between each pair of Recon methods, save all statistics and p-values to csv
        # df_mannwhitneyu_results = pd.DataFrame()
        # for recon in recon_list:
        #     for recon2 in recon_list:
        #         if recon != recon2:
        #             # print(recon)
        #             # print(recon2)
        #             # print(stats.mannwhitneyu(df[df['Recon']==str(recon)][str(i)],df[df['Recon']==str(recon2)][str(i)]))
        #             # calculate Mann-Whitney U test on Pearson scores, get U-statistic and p-value
        #             mannwhitneyu = stats.mannwhitneyu(df[df['Recon'] == str(
        #                 recon)][str(i)], df[df['Recon'] == str(recon2)][str(i)])
        #             # # calculate Mann-Whitney U test on Fisher's r to z transformed Pearson scores, get U-statistic and p-value
        #             # mannwhitneyu_z = stats.mannwhitneyu(df_z[df_z['Recon']==str(recon)]['z'],df_z[df_z['Recon']==str(recon2)]['z'])
        #             # combine Mann-Whitney U test results into dataframe
        #             # , 'U-statistic z-score':mannwhitneyu_z[0],'p-value z-score':mannwhitneyu_z[1]
        #             df_mannwhitneyu_results = pd.concat([df_mannwhitneyu_results, pd.DataFrame(
        #                 {'Recon 1': recon, 'Recon 2': recon2, 'U-statistic Pearson Score Mann-Whitney': mannwhitneyu[0], 'p-value Pearson Score Mann-Whitney':mannwhitneyu[1]}, index=[0])], axis=0)
        # # save dataframe to csv
        # df_mannwhitneyu_results.to_csv(
        #     main_path+'/'+file.stem+'_walk_length_'+str(i)+'_mannwhitneyu_results.csv', index=False)
# Out:
# /home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/mean_length_all_percent_batch26.csv
# mean_length_all_percent_batch26
# Walk Length: 1
# MSMT CSD Mean Length
# 0     0.357959
# 1     0.198632
# 2     0.348130
# 3     0.252825
# 4     0.301341
# 5     0.477540
# 6     0.421624
# 7     0.434281
# 8     0.455945
# 9     0.220632
# 10    0.374796
# 11    0.352692
# 12    0.365303
# 13    0.366185
# 14    0.384996
# 15    0.273719
# 16    0.341852
# 17    0.342268
# 18    0.319967
# 19    0.460355
# 20    0.445645
# Name: 1, dtype: float64
# Statistics for MSMT CSD Mean Length
# Mean
# 0.3569850782912871
# Stdev
# 0.07769852387819227
# Median
# 0.3579586163656797
# IQR
# 0.1016568172778618
# GQI Mean Length
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# Name: 1, dtype: float64
# Statistics for GQI Mean Length
# Mean
# nan
# Stdev
# nan
# Median
# nan
# IQR
# nan
# DTI Mean Length
# 42    0.494375
# 43    0.370792
# 44    0.459570
# 45    0.364898
# 46    0.456349
# 47    0.551395
# 48    0.511341
# 49    0.559699
# 50    0.550068
# 51    0.422098
# 52    0.356438
# 53    0.439981
# 54    0.475889
# 55    0.541571
# 56    0.485451
# 57    0.402848
# 58    0.392980
# 59    0.505713
# 60    0.469764
# 61    0.540413
# 62    0.556297
# Name: 1, dtype: float64
# Statistics for DTI Mean Length
# Mean
# 0.4718063337555603
# Stdev
# 0.06712329124947551
# Median
# 0.4758890309568668
# IQR
# 0.11831541713574989
#                   Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD Mean Length  0.471806  0.067123  0.475889  0.118315
# 1       GQI Mean Length  0.471806  0.067123  0.475889  0.118315
# 2       DTI Mean Length  0.471806  0.067123  0.475889  0.118315
# 0  MSMT CSD Mean Length       NaN       NaN       NaN       NaN
# 1       GQI Mean Length       NaN       NaN       NaN       NaN
# 2       DTI Mean Length       NaN       NaN       NaN       NaN
# 0  MSMT CSD Mean Length  0.356985  0.077699  0.357959  0.101657
# 1       GQI Mean Length  0.356985  0.077699  0.357959  0.101657
# 2       DTI Mean Length  0.356985  0.077699  0.357959  0.101657
# MSMT CSD Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# GQI Mean Length
# DTI Mean Length
# DTI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# T-test ind results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                         -5.124578                      0.000004
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                          5.124578                      0.999996
# 0                               NaN                           NaN
# T-test rel results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                        -10.830435                  4.069062e-10
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                         10.830435                  1.000000e+00
# 0                               NaN                           NaN
# T-test ind z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                         NaN
# 0  MSMT CSD Mean Length       DTI Mean Length                   -5.173974
# 0       GQI Mean Length  MSMT CSD Mean Length                         NaN
# 0       GQI Mean Length       DTI Mean Length                         NaN
# 0       DTI Mean Length  MSMT CSD Mean Length                    5.173974
# 0       DTI Mean Length       GQI Mean Length                         NaN
#
#    p-value z-score t-test
# 0                     NaN
# 0                0.000003
# 0                     NaN
# 0                     NaN
# 0                0.999997
# 0                     NaN
# T-test rel z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                         NaN
# 0  MSMT CSD Mean Length       DTI Mean Length                  -11.421211
# 0       GQI Mean Length  MSMT CSD Mean Length                         NaN
# 0       GQI Mean Length       DTI Mean Length                         NaN
# 0       DTI Mean Length  MSMT CSD Mean Length                   11.421211
# 0       DTI Mean Length       GQI Mean Length                         NaN
#
#    p-value z-score t-test
# 0                     NaN
# 0            1.619993e-10
# 0                     NaN
# 0                     NaN
# 0            1.000000e+00
# 0                     NaN
# Walk Length: 2
# MSMT CSD Mean Length
# 0     0.360374
# 1     0.205422
# 2     0.348417
# 3     0.251356
# 4     0.305423
# 5     0.493605
# 6     0.421172
# 7     0.436106
# 8     0.461185
# 9     0.219896
# 10    0.380020
# 11    0.375053
# 12    0.364861
# 13    0.367292
# 14    0.387899
# 15    0.295159
# 16    0.354939
# 17    0.343695
# 18    0.335114
# 19    0.467288
# 20    0.441744
# Name: 2, dtype: float64
# Statistics for MSMT CSD Mean Length
# Mean
# 0.3626677756796378
# Stdev
# 0.0776864903175044
# Median
# 0.3648608470393938
# IQR
# 0.08605793484604518
# GQI Mean Length
# 21    0.359966
# 22    0.205383
# 23    0.289607
# 24    0.222222
# 25    0.310361
# 26    0.491091
# 27    0.399216
# 28    0.449689
# 29    0.290538
# 30    0.243428
# 31    0.318381
# 32    0.312507
# 33    0.321910
# 34    0.372398
# 35    0.387222
# 36    0.272396
# 37    0.331004
# 38    0.357749
# 39    0.333058
# 40    0.457177
# 41    0.438522
# Name: 2, dtype: float64
# Statistics for GQI Mean Length
# Mean
# 0.341134514533264
# Stdev
# 0.07720215933561829
# Median
# 0.331004027410148
# IQR
# 0.09668462209940198
# DTI Mean Length
# 42    0.494641
# 43    0.445759
# 44    0.558641
# 45    0.391966
# 46    0.521312
# 47    0.645543
# 48    0.561015
# 49    0.628110
# 50    0.617601
# 51    0.520776
# 52    0.445380
# 53    0.547567
# 54    0.595668
# 55    0.611483
# 56    0.565344
# 57    0.513675
# 58    0.528737
# 59    0.477327
# 60    0.534176
# 61    0.572739
# 62    0.623659
# Name: 2, dtype: float64
# Statistics for DTI Mean Length
# Mean
# 0.5429103500600341
# Stdev
# 0.06701540288702386
# Median
# 0.5475665705259688
# IQR
# 0.08199224266350214
#                   Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD Mean Length  0.542910  0.067015  0.547567  0.081992
# 1       GQI Mean Length  0.542910  0.067015  0.547567  0.081992
# 2       DTI Mean Length  0.542910  0.067015  0.547567  0.081992
# 0  MSMT CSD Mean Length  0.341135  0.077202  0.331004  0.096685
# 1       GQI Mean Length  0.341135  0.077202  0.331004  0.096685
# 2       DTI Mean Length  0.341135  0.077202  0.331004  0.096685
# 0  MSMT CSD Mean Length  0.362668  0.077686  0.364861  0.086058
# 1       GQI Mean Length  0.362668  0.077686  0.364861  0.086058
# 2       DTI Mean Length  0.362668  0.077686  0.364861  0.086058
# MSMT CSD Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/paul/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1956: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0
# GQI Mean Length
# MSMT CSD Mean Length
# GQI Mean Length
# DTI Mean Length
# DTI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# T-test ind results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          0.900975                  8.135027e-01
# 0                         -8.050634                  3.375130e-10
# 0                         -0.900975                  1.864973e-01
# 0                         -9.044716                  1.608593e-11
# 0                          8.050634                  1.000000e+00
# 0                          9.044716                  1.000000e+00
# T-test rel results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          2.328120                  9.847440e-01
# 0                        -15.512875                  6.462673e-13
# 0                         -2.328120                  1.525598e-02
# 0                        -15.940720                  3.899284e-13
# 0                         15.512875                  1.000000e+00
# 0                         15.940720                  1.000000e+00
# T-test ind z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                    0.900023
# 0  MSMT CSD Mean Length       DTI Mean Length                   -8.121729
# 0       GQI Mean Length  MSMT CSD Mean Length                   -0.900023
# 0       GQI Mean Length       DTI Mean Length                   -9.026560
# 0       DTI Mean Length  MSMT CSD Mean Length                    8.121729
# 0       DTI Mean Length       GQI Mean Length                    9.026560
#
#    p-value z-score t-test
# 0            8.132527e-01
# 0            2.705092e-10
# 0            1.867473e-01
# 0            1.698802e-11
# 0            1.000000e+00
# 0            1.000000e+00
# T-test rel z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                    2.308798
# 0  MSMT CSD Mean Length       DTI Mean Length                  -16.216433
# 0       GQI Mean Length  MSMT CSD Mean Length                   -2.308798
# 0       GQI Mean Length       DTI Mean Length                  -16.175716
# 0       DTI Mean Length  MSMT CSD Mean Length                   16.216433
# 0       DTI Mean Length       GQI Mean Length                   16.175716
#
#    p-value z-score t-test
# 0            9.841188e-01
# 0            2.833025e-13
# 0            1.588123e-02
# 0            2.968997e-13
# 0            1.000000e+00
# 0            1.000000e+00
# Walk Length: 3
# MSMT CSD Mean Length
# 0     0.360376
# 1     0.205423
# 2     0.348417
# 3     0.251352
# 4     0.305426
# 5     0.493609
# 6     0.421172
# 7     0.436113
# 8     0.461185
# 9     0.219897
# 10    0.380013
# 11    0.375051
# 12    0.364859
# 13    0.367290
# 14    0.387900
# 15    0.295158
# 16    0.354942
# 17    0.343700
# 18    0.335110
# 19    0.467291
# 20    0.441747
# Name: 3, dtype: float64
# Statistics for MSMT CSD Mean Length
# Mean
# 0.36266811416512534
# Stdev
# 0.07768740287501733
# Median
# 0.3648588039774265
# IQR
# 0.08606198217352784
# GQI Mean Length
# 21    0.361640
# 22    0.205325
# 23    0.289318
# 24    0.221291
# 25    0.309751
# 26    0.492427
# 27    0.401523
# 28    0.449323
# 29    0.291156
# 30    0.244084
# 31    0.317602
# 32    0.311388
# 33    0.322786
# 34    0.371697
# 35    0.386369
# 36    0.272470
# 37    0.332402
# 38    0.358548
# 39    0.332136
# 40    0.458251
# 41    0.439298
# Name: 3, dtype: float64
# Statistics for GQI Mean Length
# Mean
# 0.34137067610106053
# Stdev
# 0.07756825140954361
# Median
# 0.3321356485127945
# IQR
# 0.09521279328611176
# DTI Mean Length
# 42    0.515705
# 43    0.454787
# 44    0.594178
# 45    0.404417
# 46    0.557721
# 47    0.648889
# 48    0.583746
# 49    0.642330
# 50    0.628333
# 51    0.547481
# 52    0.460282
# 53    0.580548
# 54    0.624082
# 55    0.644957
# 56    0.578516
# 57    0.558966
# 58    0.549911
# 59    0.479228
# 60    0.537489
# 61    0.588747
# 62    0.610942
# Name: 3, dtype: float64
# Statistics for DTI Mean Length
# Mean
# 0.5614882272078457
# Stdev
# 0.06746191109719948
# Median
# 0.5785164173481269
# IQR
# 0.07345311272032717
#                   Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD Mean Length  0.561488  0.067462  0.578516  0.073453
# 1       GQI Mean Length  0.561488  0.067462  0.578516  0.073453
# 2       DTI Mean Length  0.561488  0.067462  0.578516  0.073453
# 0  MSMT CSD Mean Length  0.341371  0.077568  0.332136  0.095213
# 1       GQI Mean Length  0.341371  0.077568  0.332136  0.095213
# 2       DTI Mean Length  0.341371  0.077568  0.332136  0.095213
# 0  MSMT CSD Mean Length  0.362668  0.077687  0.364859  0.086062
# 1       GQI Mean Length  0.362668  0.077687  0.364859  0.086062
# 2       DTI Mean Length  0.362668  0.077687  0.364859  0.086062
# MSMT CSD Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# GQI Mean Length
# DTI Mean Length
# DTI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# T-test ind results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          0.889006                  8.103423e-01
# 0                         -8.855130                  2.849235e-11
# 0                         -0.889006                  1.896577e-01
# 0                         -9.812261                  1.663190e-12
# 0                          8.855130                  1.000000e+00
# 0                          9.812261                  1.000000e+00
# T-test rel results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                          2.299483                  9.838090e-01
# 0                        -15.227362                  9.114611e-13
# 0                         -2.299483                  1.619105e-02
# 0                        -15.481092                  6.713031e-13
# 0                         15.227362                  1.000000e+00
# 0                         15.481092                  1.000000e+00
# T-test ind z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                    0.886974
# 0  MSMT CSD Mean Length       DTI Mean Length                   -8.976255
# 0       GQI Mean Length  MSMT CSD Mean Length                   -0.886974
# 0       GQI Mean Length       DTI Mean Length                   -9.840120
# 0       DTI Mean Length  MSMT CSD Mean Length                    8.976255
# 0       DTI Mean Length       GQI Mean Length                    9.840120
#
#    p-value z-score t-test
# 0            8.098026e-01
# 0            1.976456e-11
# 0            1.901974e-01
# 0            1.533837e-12
# 0            1.000000e+00
# 0            1.000000e+00
# T-test rel z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                    2.278457
# 0  MSMT CSD Mean Length       DTI Mean Length                  -15.723964
# 0       GQI Mean Length  MSMT CSD Mean Length                   -2.278457
# 0       GQI Mean Length       DTI Mean Length                  -15.614922
# 0       DTI Mean Length  MSMT CSD Mean Length                   15.723964
# 0       DTI Mean Length       GQI Mean Length                   15.614922
#
#    p-value z-score t-test
# 0            9.830891e-01
# 0            5.029348e-13
# 0            1.691092e-02
# 0            5.722806e-13
# 0            1.000000e+00
# 0            1.000000e+00
# Walk Length: 4
# MSMT CSD Mean Length
# 0     0.360417
# 1     0.205408
# 2     0.348387
# 3     0.251331
# 4     0.305453
# 5     0.493652
# 6     0.421236
# 7     0.436124
# 8     0.461230
# 9     0.219958
# 10    0.380003
# 11    0.374974
# 12    0.364875
# 13    0.367364
# 14    0.387904
# 15    0.295124
# 16    0.354987
# 17    0.343772
# 18    0.335042
# 19    0.467362
# 20    0.441816
# Name: 4, dtype: float64
# Statistics for MSMT CSD Mean Length
# Mean
# 0.3626866032158393
# Stdev
# 0.07770294085724026
# Median
# 0.3648745428485583
# IQR
# 0.08619350263189896
# GQI Mean Length
# 21    0.398274
# 22    0.255862
# 23    0.397859
# 24    0.287246
# 25    0.366544
# 26    0.540405
# 27    0.451748
# 28    0.506895
# 29    0.362794
# 30    0.296200
# 31    0.439727
# 32    0.399215
# 33    0.418836
# 34    0.444879
# 35    0.452069
# 36    0.350919
# 37    0.397121
# 38    0.372276
# 39    0.390891
# 40    0.476683
# 41    0.507270
# Name: 4, dtype: float64
# Statistics for GQI Mean Length
# Mean
# 0.4054148742593978
# Stdev
# 0.0732433472143208
# Median
# 0.3982737701496877
# IQR
# 0.0852036846524315
# DTI Mean Length
# 42    0.508242
# 43    0.441587
# 44    0.589740
# 45    0.410728
# 46    0.557654
# 47    0.655310
# 48    0.580782
# 49    0.640391
# 50    0.633890
# 51    0.564879
# 52    0.454469
# 53    0.583074
# 54    0.623178
# 55    0.645819
# 56    0.578014
# 57    0.550526
# 58    0.542911
# 59    0.475334
# 60    0.537206
# 61    0.590791
# 62    0.609627
# Name: 4, dtype: float64
# Statistics for DTI Mean Length
# Mean
# 0.5606739978413474
# Stdev
# 0.06933831377173681
# Median
# 0.5780142863498884
# IQR
# 0.07242032097965012
#                   Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD Mean Length  0.560674  0.069338  0.578014  0.072420
# 1       GQI Mean Length  0.560674  0.069338  0.578014  0.072420
# 2       DTI Mean Length  0.560674  0.069338  0.578014  0.072420
# 0  MSMT CSD Mean Length  0.405415  0.073243  0.398274  0.085204
# 1       GQI Mean Length  0.405415  0.073243  0.398274  0.085204
# 2       DTI Mean Length  0.405415  0.073243  0.398274  0.085204
# 0  MSMT CSD Mean Length  0.362687  0.077703  0.364875  0.086194
# 1       GQI Mean Length  0.362687  0.077703  0.364875  0.086194
# 2       DTI Mean Length  0.362687  0.077703  0.364875  0.086194
# MSMT CSD Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# GQI Mean Length
# DTI Mean Length
# DTI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# T-test ind results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -1.833699                  3.707339e-02
# 0                         -8.712071                  4.398530e-11
# 0                          1.833699                  9.629266e-01
# 0                         -7.054322                  7.879602e-09
# 0                          8.712071                  1.000000e+00
# 0                          7.054322                  1.000000e+00
# T-test rel results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -5.317417                  1.663972e-05
# 0                        -14.797889                  1.544864e-12
# 0                          5.317417                  9.999834e-01
# 0                        -11.944757                  7.374946e-11
# 0                         14.797889                  1.000000e+00
# 0                         11.944757                  1.000000e+00
# T-test ind z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -1.841752
# 0  MSMT CSD Mean Length       DTI Mean Length                   -8.805483
# 0       GQI Mean Length  MSMT CSD Mean Length                    1.841752
# 0       GQI Mean Length       DTI Mean Length                   -7.121278
# 0       DTI Mean Length  MSMT CSD Mean Length                    8.805483
# 0       DTI Mean Length       GQI Mean Length                    7.121278
#
#    p-value z-score t-test
# 0            3.646731e-02
# 0            3.311724e-11
# 0            9.635327e-01
# 0            6.360157e-09
# 0            1.000000e+00
# 0            1.000000e+00
# T-test rel z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -5.219463
# 0  MSMT CSD Mean Length       DTI Mean Length                  -15.168937
# 0       GQI Mean Length  MSMT CSD Mean Length                    5.219463
# 0       GQI Mean Length       DTI Mean Length                  -12.053657
# 0       DTI Mean Length  MSMT CSD Mean Length                   15.168937
# 0       DTI Mean Length       GQI Mean Length                   12.053657
#
#    p-value z-score t-test
# 0            2.079334e-05
# 0            9.785609e-13
# 0            9.999792e-01
# 0            6.282189e-11
# 0            1.000000e+00
# 0            1.000000e+00
# Walk Length: 5
# MSMT CSD Mean Length
# 0     0.383354
# 1     0.265078
# 2     0.390211
# 3     0.305042
# 4     0.352516
# 5     0.541738
# 6     0.434073
# 7     0.498536
# 8     0.496624
# 9     0.272115
# 10    0.435992
# 11    0.439410
# 12    0.388663
# 13    0.412078
# 14    0.454578
# 15    0.343054
# 16    0.378125
# 17    0.367425
# 18    0.351480
# 19    0.472164
# 20    0.451485
# Name: 5, dtype: float64
# Statistics for MSMT CSD Mean Length
# Mean
# 0.40160665240064974
# Stdev
# 0.0733285910030678
# Median
# 0.3902106718079766
# IQR
# 0.09896884600293238
# GQI Mean Length
# 21    0.401472
# 22    0.256536
# 23    0.402656
# 24    0.294025
# 25    0.366398
# 26    0.537718
# 27    0.453208
# 28    0.510822
# 29    0.362561
# 30    0.291199
# 31    0.440428
# 32    0.405500
# 33    0.423503
# 34    0.444332
# 35    0.454467
# 36    0.350389
# 37    0.403331
# 38    0.372204
# 39    0.387175
# 40    0.477203
# 41    0.513919
# Name: 5, dtype: float64
# Statistics for GQI Mean Length
# Mean
# 0.40709734483682536
# Stdev
# 0.07372497940266332
# Median
# 0.4033310225860143
# IQR
# 0.08681068076888782
# DTI Mean Length
# 42    0.504803
# 43    0.445083
# 44    0.587536
# 45    0.415937
# 46    0.559341
# 47    0.659397
# 48    0.579369
# 49    0.641186
# 50    0.630696
# 51    0.580808
# 52    0.455844
# 53    0.592111
# 54    0.622645
# 55    0.646731
# 56    0.578819
# 57    0.548963
# 58    0.541962
# 59    0.474449
# 60    0.540282
# 61    0.594350
# 62    0.607970
# Name: 5, dtype: float64
# Statistics for DTI Mean Length
# Mean
# 0.5622991816263654
# Stdev
# 0.0690099454066742
# Median
# 0.579369084978776
# IQR
# 0.06768756146724231
#                   Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD Mean Length  0.562299  0.069010  0.579369  0.067688
# 1       GQI Mean Length  0.562299  0.069010  0.579369  0.067688
# 2       DTI Mean Length  0.562299  0.069010  0.579369  0.067688
# 0  MSMT CSD Mean Length  0.407097  0.073725  0.403331  0.086811
# 1       GQI Mean Length  0.407097  0.073725  0.403331  0.086811
# 2       DTI Mean Length  0.407097  0.073725  0.403331  0.086811
# 0  MSMT CSD Mean Length  0.401607  0.073329  0.390211  0.098969
# 1       GQI Mean Length  0.401607  0.073329  0.390211  0.098969
# 2       DTI Mean Length  0.401607  0.073329  0.390211  0.098969
# MSMT CSD Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# MSMT CSD Mean Length
# GQI Mean Length
# DTI Mean Length
# DTI Mean Length
# MSMT CSD Mean Length
# DTI Mean Length
# GQI Mean Length
# T-test ind results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -0.241977                  4.050170e-01
# 0                         -7.313041                  3.449605e-09
# 0                          0.241977                  5.949830e-01
# 0                         -7.042947                  8.171895e-09
# 0                          7.313041                  1.000000e+00
# 0                          7.042947                  1.000000e+00
# T-test rel results
#                 Recon 1               Recon 2  \
# 0  MSMT CSD Mean Length       GQI Mean Length
# 0  MSMT CSD Mean Length       DTI Mean Length
# 0       GQI Mean Length  MSMT CSD Mean Length
# 0       GQI Mean Length       DTI Mean Length
# 0       DTI Mean Length  MSMT CSD Mean Length
# 0       DTI Mean Length       GQI Mean Length
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                         -0.667240                  2.561223e-01
# 0                        -12.257329                  4.668135e-11
# 0                          0.667240                  7.438777e-01
# 0                        -11.506759                  1.421911e-10
# 0                         12.257329                  1.000000e+00
# 0                         11.506759                  1.000000e+00
# T-test ind z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -0.243747
# 0  MSMT CSD Mean Length       DTI Mean Length                   -7.371130
# 0       GQI Mean Length  MSMT CSD Mean Length                    0.243747
# 0       GQI Mean Length       DTI Mean Length                   -7.115934
# 0       DTI Mean Length  MSMT CSD Mean Length                    7.371130
# 0       DTI Mean Length       GQI Mean Length                    7.115934
#
#    p-value z-score t-test
# 0            4.043363e-01
# 0            2.867616e-09
# 0            5.956637e-01
# 0            6.469774e-09
# 0            1.000000e+00
# 0            1.000000e+00
# T-test rel z-score results
#                 Recon 1               Recon 2  T-statistic z-score t-test  \
# 0  MSMT CSD Mean Length       GQI Mean Length                   -0.655172
# 0  MSMT CSD Mean Length       DTI Mean Length                  -12.561336
# 0       GQI Mean Length  MSMT CSD Mean Length                    0.655172
# 0       GQI Mean Length       DTI Mean Length                  -11.681164
# 0       DTI Mean Length  MSMT CSD Mean Length                   12.561336
# 0       DTI Mean Length       GQI Mean Length                   11.681164
#
#    p-value z-score t-test
# 0            2.599111e-01
# 0            3.017925e-11
# 0            7.400889e-01
# 0            1.092380e-10
# 0            1.000000e+00
# 0            1.000000e+00
# /home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/count_all_percent_batch26.csv
# count_all_percent_batch26
# Walk Length: 1
# MSMT CSD SIFT2 Streamline Count
# 0     0.343514
# 1     0.179354
# 2     0.311512
# 3     0.252634
# 4     0.290706
# 5     0.484446
# 6     0.419338
# 7     0.424149
# 8     0.439686
# 9     0.203237
# 10    0.344745
# 11    0.330928
# 12    0.373944
# 13    0.338384
# 14    0.363774
# 15    0.299135
# 16    0.332314
# 17    0.347855
# 18    0.336286
# 19    0.432913
# 20    0.453295
# Name: 1, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.34772141358643627
# Stdev
# 0.07855616457760861
# Median
# 0.3435141858526813
# IQR
# 0.10782552645491311
# GQI Streamline Count
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# Name: 1, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# nan
# Stdev
# nan
# Median
# nan
# IQR
# nan
# DTI Streamline Count
# 42    0.361918
# 43    0.208547
# 44    0.312811
# 45    0.204903
# 46    0.280900
# 47    0.443902
# 48    0.451568
# 49    0.393700
# 50    0.443357
# 51    0.224940
# 52    0.351231
# 53    0.315052
# 54    0.337499
# 55    0.330608
# 56    0.385346
# 57    0.283453
# 58    0.312078
# 59    0.343519
# 60    0.323446
# 61    0.428972
# 62    0.447169
# Name: 1, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.3421390417936493
# Stdev
# 0.07640670293902185
# Median
# 0.3374991768966722
# IQR
# 0.0816222226768929
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.342139  0.076407  0.337499  0.081622
# 1             GQI Streamline Count  0.342139  0.076407  0.337499  0.081622
# 2             DTI Streamline Count  0.342139  0.076407  0.337499  0.081622
# 0  MSMT CSD SIFT2 Streamline Count       NaN       NaN       NaN       NaN
# 1             GQI Streamline Count       NaN       NaN       NaN       NaN
# 2             DTI Streamline Count       NaN       NaN       NaN       NaN
# 0  MSMT CSD SIFT2 Streamline Count  0.347721  0.078556  0.343514  0.107826
# 1             GQI Streamline Count  0.347721  0.078556  0.343514  0.107826
# 2             DTI Streamline Count  0.347721  0.078556  0.343514  0.107826
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# DTI Streamline Count
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/paul/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1956: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/paul/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1956: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                          0.233439                      0.591695
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                         -0.233439                      0.408305
# 0                               NaN                           NaN
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                          1.141358                      0.866398
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                         -1.141358                      0.133602
# 0                               NaN                           NaN
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                     0.23967                0.594095
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                    -0.23967                0.405905
# 0                         NaN                     NaN
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                    1.162028                0.870548
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                   -1.162028                0.129452
# 0                         NaN                     NaN
# Walk Length: 2
# MSMT CSD SIFT2 Streamline Count
# 0     0.347881
# 1     0.185848
# 2     0.309715
# 3     0.248553
# 4     0.295859
# 5     0.485462
# 6     0.424219
# 7     0.428899
# 8     0.438625
# 9     0.206323
# 10    0.342058
# 11    0.326550
# 12    0.371833
# 13    0.343620
# 14    0.365100
# 15    0.297691
# 16    0.334327
# 17    0.351109
# 18    0.334579
# 19    0.436819
# 20    0.457369
# Name: 2, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.349163670834657
# Stdev
# 0.07874231537874278
# Median
# 0.3436203656046738
# IQR
# 0.11450349314707786
# GQI Streamline Count
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# Name: 2, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# nan
# Stdev
# nan
# Median
# nan
# IQR
# nan
# DTI Streamline Count
# 42    0.363379
# 43    0.208597
# 44    0.312675
# 45    0.204566
# 46    0.281279
# 47    0.446013
# 48    0.451817
# 49    0.395325
# 50    0.444023
# 51    0.225593
# 52    0.350931
# 53    0.315395
# 54    0.338480
# 55    0.330963
# 56    0.386147
# 57    0.283269
# 58    0.312266
# 59    0.342987
# 60    0.322106
# 61    0.430055
# 62    0.448355
# Name: 2, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.3425820621019251
# Stdev
# 0.0768207224889068
# Median
# 0.3384804026803313
# IQR
# 0.08305905842529299
#                              Recon      Mean     Stdev   Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.342582  0.076821  0.33848  0.083059
# 1             GQI Streamline Count  0.342582  0.076821  0.33848  0.083059
# 2             DTI Streamline Count  0.342582  0.076821  0.33848  0.083059
# 0  MSMT CSD SIFT2 Streamline Count       NaN       NaN      NaN       NaN
# 1             GQI Streamline Count       NaN       NaN      NaN       NaN
# 2             DTI Streamline Count       NaN       NaN      NaN       NaN
# 0  MSMT CSD SIFT2 Streamline Count  0.349164  0.078742  0.34362  0.114503
# 1             GQI Streamline Count  0.349164  0.078742  0.34362  0.114503
# 2             DTI Streamline Count  0.349164  0.078742  0.34362  0.114503
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# DTI Streamline Count
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                          0.274168                      0.607317
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                         -0.274168                      0.392683
# 0                               NaN                           NaN
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                          1.436906                      0.916897
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                         -1.436906                      0.083103
# 0                               NaN                           NaN
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                    0.280517                0.609737
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                   -0.280517                0.390263
# 0                         NaN                     NaN
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                    1.451724                0.918957
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                   -1.451724                0.081043
# 0                         NaN                     NaN
# Walk Length: 3
# MSMT CSD SIFT2 Streamline Count
# 0     0.348637
# 1     0.186983
# 2     0.308876
# 3     0.247173
# 4     0.297020
# 5     0.485406
# 6     0.425207
# 7     0.429300
# 8     0.438311
# 9     0.206956
# 10    0.341544
# 11    0.325104
# 12    0.371026
# 13    0.344759
# 14    0.365022
# 15    0.297082
# 16    0.334704
# 17    0.351583
# 18    0.334050
# 19    0.437762
# 20    0.457851
# Name: 3, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.3492550596062907
# Stdev
# 0.07879952768977552
# Median
# 0.3447588070751096
# IQR
# 0.11633083791749521
# GQI Streamline Count
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# Name: 3, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# nan
# Stdev
# nan
# Median
# nan
# IQR
# nan
# DTI Streamline Count
# 42    0.364548
# 43    0.208708
# 44    0.312566
# 45    0.204231
# 46    0.281600
# 47    0.447674
# 48    0.451975
# 49    0.396753
# 50    0.444556
# 51    0.226042
# 52    0.350630
# 53    0.315634
# 54    0.339268
# 55    0.331158
# 56    0.386708
# 57    0.282941
# 58    0.312391
# 59    0.342464
# 60    0.320914
# 61    0.430856
# 62    0.449212
# Name: 3, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.3428965843121327
# Stdev
# 0.0771587400552083
# Median
# 0.3392683295172781
# IQR
# 0.08436285025052143
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.342897  0.077159  0.339268  0.084363
# 1             GQI Streamline Count  0.342897  0.077159  0.339268  0.084363
# 2             DTI Streamline Count  0.342897  0.077159  0.339268  0.084363
# 0  MSMT CSD SIFT2 Streamline Count       NaN       NaN       NaN       NaN
# 1             GQI Streamline Count       NaN       NaN       NaN       NaN
# 2             DTI Streamline Count       NaN       NaN       NaN       NaN
# 0  MSMT CSD SIFT2 Streamline Count  0.349255  0.078800  0.344759  0.116331
# 1             GQI Streamline Count  0.349255  0.078800  0.344759  0.116331
# 2             DTI Streamline Count  0.349255  0.078800  0.344759  0.116331
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# DTI Streamline Count
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                          0.264208                      0.603512
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                         -0.264208                      0.396488
# 0                               NaN                           NaN
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                          1.414547                      0.913709
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                         -1.414547                      0.086291
# 0                               NaN                           NaN
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                    0.269804                0.605651
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                   -0.269804                0.394349
# 0                         NaN                     NaN
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                    1.427719                0.915599
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                   -1.427719                0.084401
# 0                         NaN                     NaN
# Walk Length: 4
# MSMT CSD SIFT2 Streamline Count
# 0     0.348637
# 1     0.186984
# 2     0.308874
# 3     0.247170
# 4     0.297022
# 5     0.485406
# 6     0.425210
# 7     0.429302
# 8     0.438310
# 9     0.206958
# 10    0.341542
# 11    0.325100
# 12    0.371025
# 13    0.344761
# 14    0.365023
# 15    0.297081
# 16    0.334706
# 17    0.351584
# 18    0.334046
# 19    0.437763
# 20    0.457853
# Name: 4, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.3492550315228384
# Stdev
# 0.07880007061450582
# Median
# 0.3447613952063325
# IQR
# 0.1163353862634589
# GQI Streamline Count
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# Name: 4, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# nan
# Stdev
# nan
# Median
# nan
# IQR
# nan
# DTI Streamline Count
# 42    0.356952
# 43    0.211859
# 44    0.333097
# 45    0.213197
# 46    0.300323
# 47    0.467602
# 48    0.467846
# 49    0.416353
# 50    0.475118
# 51    0.235712
# 52    0.369304
# 53    0.348432
# 54    0.369753
# 55    0.355154
# 56    0.389199
# 57    0.284895
# 58    0.343535
# 59    0.343186
# 60    0.330263
# 61    0.436254
# 62    0.455830
# Name: 4, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.35732683335085486
# Stdev
# 0.07937074393006999
# Median
# 0.3551541028100775
# IQR
# 0.0860896907759039
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.357327  0.079371  0.355154  0.086090
# 1             GQI Streamline Count  0.357327  0.079371  0.355154  0.086090
# 2             DTI Streamline Count  0.357327  0.079371  0.355154  0.086090
# 0  MSMT CSD SIFT2 Streamline Count       NaN       NaN       NaN       NaN
# 1             GQI Streamline Count       NaN       NaN       NaN       NaN
# 2             DTI Streamline Count       NaN       NaN       NaN       NaN
# 0  MSMT CSD SIFT2 Streamline Count  0.349255  0.078800  0.344761  0.116335
# 1             GQI Streamline Count  0.349255  0.078800  0.344761  0.116335
# 2             DTI Streamline Count  0.349255  0.078800  0.344761  0.116335
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# DTI Streamline Count
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/paul/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1956: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/paul/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1956: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0
# DTI Streamline Count
# GQI Streamline Count
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                         -0.330724                       0.37129
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                          0.330724                       0.62871
# 0                               NaN                           NaN
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                         -1.863214                      0.038592
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                          1.863214                      0.961408
# 0                               NaN                           NaN
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                    -0.33505                0.369669
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                     0.33505                0.630331
# 0                         NaN                     NaN
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                    -1.85502                0.039198
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                     1.85502                0.960802
# 0                         NaN                     NaN
# Walk Length: 5
# MSMT CSD SIFT2 Streamline Count
# 0     0.348637
# 1     0.186984
# 2     0.308873
# 3     0.247168
# 4     0.297023
# 5     0.485406
# 6     0.425212
# 7     0.429303
# 8     0.438308
# 9     0.206959
# 10    0.341540
# 11    0.325097
# 12    0.371025
# 13    0.344764
# 14    0.365024
# 15    0.297079
# 16    0.334707
# 17    0.351585
# 18    0.334044
# 19    0.437764
# 20    0.457855
# Name: 5, dtype: float64
# Statistics for MSMT CSD SIFT2 Streamline Count
# Mean
# 0.34925502873818615
# Stdev
# 0.07880043658957667
# Median
# 0.3447637112499149
# IQR
# 0.11633901426711307
# GQI Streamline Count
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# Name: 5, dtype: float64
# Statistics for GQI Streamline Count
# Mean
# nan
# Stdev
# nan
# Median
# nan
# IQR
# nan
# DTI Streamline Count
# 42    0.356237
# 43    0.211488
# 44    0.332083
# 45    0.212703
# 46    0.301382
# 47    0.467543
# 48    0.468300
# 49    0.415733
# 50    0.475633
# 51    0.235766
# 52    0.369466
# 53    0.347461
# 54    0.370118
# 55    0.355903
# 56    0.388927
# 57    0.284517
# 58    0.344657
# 59    0.343533
# 60    0.329977
# 61    0.436826
# 62    0.455467
# Name: 5, dtype: float64
# Statistics for DTI Streamline Count
# Mean
# 0.3573198821953184
# Stdev
# 0.0794863545199193
# Median
# 0.3559031457948873
# IQR
# 0.08575591615411432
#                              Recon      Mean     Stdev    Median       IQR
# 0  MSMT CSD SIFT2 Streamline Count  0.357320  0.079486  0.355903  0.085756
# 1             GQI Streamline Count  0.357320  0.079486  0.355903  0.085756
# 2             DTI Streamline Count  0.357320  0.079486  0.355903  0.085756
# 0  MSMT CSD SIFT2 Streamline Count       NaN       NaN       NaN       NaN
# 1             GQI Streamline Count       NaN       NaN       NaN       NaN
# 2             DTI Streamline Count       NaN       NaN       NaN       NaN
# 0  MSMT CSD SIFT2 Streamline Count  0.349255  0.078800  0.344764  0.116339
# 1             GQI Streamline Count  0.349255  0.078800  0.344764  0.116339
# 2             DTI Streamline Count  0.349255  0.078800  0.344764  0.116339
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# GQI Streamline Count
# DTI Streamline Count
# DTI Streamline Count
# MSMT CSD SIFT2 Streamline Count
# DTI Streamline Count
# GQI Streamline Count
# T-test ind results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                         -0.330196                      0.371487
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                          0.330196                      0.628513
# 0                               NaN                           NaN
# T-test rel results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic Pearson Score t-test  p-value Pearson Score t-test
# 0                               NaN                           NaN
# 0                         -1.854668                      0.039224
# 0                               NaN                           NaN
# 0                               NaN                           NaN
# 0                          1.854668                      0.960776
# 0                               NaN                           NaN
# T-test ind z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                   -0.334801                0.369762
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                    0.334801                0.630238
# 0                         NaN                     NaN
# T-test rel z-score results
#                            Recon 1                          Recon 2  \
# 0  MSMT CSD SIFT2 Streamline Count             GQI Streamline Count
# 0  MSMT CSD SIFT2 Streamline Count             DTI Streamline Count
# 0             GQI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             GQI Streamline Count             DTI Streamline Count
# 0             DTI Streamline Count  MSMT CSD SIFT2 Streamline Count
# 0             DTI Streamline Count             GQI Streamline Count
#
#    T-statistic z-score t-test  p-value z-score t-test
# 0                         NaN                     NaN
# 0                   -1.846512                0.039835
# 0                         NaN                     NaN
# 0                         NaN                     NaN
# 0                    1.846512                0.960165
# 0                         NaN                     NaN
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /home/paul/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1956: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0

# %% [markdown]
# Make Box Plots

# %%
# Read data
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/'
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/'
file_list = Path(main_path).glob('*batch??.csv')
for file in file_list:
    print(file)
    df = pd.read_csv(file)
    print(file.stem)
    # melt data for boxplot
    dd=pd.melt(df,id_vars=['Recon'],value_vars=['1','2','3','4','5'],var_name='Walk Length')
    # seaborn boxplot with hue based on recon method
    sns.boxplot(x='Walk Length',y='value',data=dd,hue='Recon')
    # plt.show()
    plt.ylabel('Pearson Score')
    # save figure
    plt.savefig(main_path+'/'+file.stem+'_box_plot.png')
    plt.close()
# Out:
# /home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/mean_length_all_percent_batch26.csv
# mean_length_all_percent_batch26
# /home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/count_all_percent_batch26.csv
# count_all_percent_batch26

# %%
# read in z-score paired t-test results from all batches in main_path/stats with walk length 4
main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/'
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/'
file_list = Path(main_path+'/stats').glob('volume_*_walk_length_4_z_score_ttest_rel_results.csv')
df = pd.DataFrame()
for file in file_list:
    print(file)
    df = pd.concat([df,pd.read_csv(file)],axis=0)
# get mean and standard deviation, max, min of t-statistic and p-value for the row where Recon 1 is DTI Node Volume Weighted Streamline Count and Recon 2 is MSMT CSD SIFT2 Node Volume Weighted Streamline Count
print('mean')
print(df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].mean())
print('std')
print(df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].std())
print('max')
print(df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].max())
print('min')
print(df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].min())

# save out mean, std, max, min to csv
df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].mean().to_csv(main_path+'/stats/walk_4_volume_weighted_paired_ttest_results_mean.csv')
df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].std().to_csv(main_path+'/stats/walk_4_volume_weighted_paired_ttest_results_std.csv')
df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].max().to_csv(main_path+'/stats/walk_4_volume_weighted_paired_ttest_results_max.csv')
df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].min().to_csv(main_path+'/stats/walk_4_volume_weighted_paired_ttest_results_min.csv')
# Out:
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch60_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch14_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch85_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch26_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch53_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch77_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch25_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch27_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch52_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch12_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch44_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch70_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch47_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch19_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch79_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch39_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch95_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch35_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch37_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch84_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch67_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch86_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch16_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch32_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch62_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch69_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch51_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch21_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch87_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch20_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch18_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch22_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch83_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch97_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch68_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch28_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch45_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch94_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch90_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch76_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch30_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch73_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch99_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch78_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch46_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch63_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch29_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch24_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch34_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch17_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch50_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch54_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch48_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch66_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch80_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch23_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch65_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch11_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch13_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch92_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch10_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch42_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch72_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch43_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch40_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch56_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch55_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch59_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch96_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch61_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch93_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch81_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch91_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch58_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch75_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch31_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch57_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch38_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch89_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch41_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch36_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch33_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch49_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch15_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch98_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch64_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch71_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch88_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch82_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/volume_weighted_all_percent_batch74_walk_length_4_z_score_ttest_rel_results.csv
# mean
# T-statistic z-score t-test   -3.416429
# p-value z-score t-test        0.027532
# dtype: float64
# std
# T-statistic z-score t-test    1.735521
# p-value z-score t-test        0.053344
# dtype: float64
# max
# Recon 1                               DTI Node Volume Weighted Streamline Count
# Recon 2                       MSMT CSD SIFT2 Node Volume Weighted Streamline...
# T-statistic z-score t-test                                            -0.448604
# p-value z-score t-test                                                  0.32927
# dtype: object
# min
# Recon 1                               DTI Node Volume Weighted Streamline Count
# Recon 2                       MSMT CSD SIFT2 Node Volume Weighted Streamline...
# T-statistic z-score t-test                                            -8.655562
# p-value z-score t-test                                                      0.0
# dtype: object
# /tmp/ipykernel_1162134/4114866491.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].mean())
# /tmp/ipykernel_1162134/4114866491.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].std())
# /tmp/ipykernel_1162134/4114866491.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].mean().to_csv(main_path+'/stats/walk_4_volume_weighted_paired_ttest_results_mean.csv')
# /tmp/ipykernel_1162134/4114866491.py:21: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['Recon 1']=='DTI Node Volume Weighted Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Node Volume Weighted Streamline Count')].std().to_csv(main_path+'/stats/walk_4_volume_weighted_paired_ttest_results_std.csv')

# %%
# read in z-score paired t-test results from all batches in main_path/stats with walk length 4
main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/'
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/'
file_list = Path(main_path+'/stats').glob('count_*_walk_length_4_z_score_ttest_rel_results.csv')
df = pd.DataFrame()
for file in file_list:
    print(file)
    df = pd.concat([df,pd.read_csv(file)],axis=0)
# get mean and standard deviation, max, min of t-statistic and p-value for the row where Recon 1 is DTI Node Volume Weighted Streamline Count and Recon 2 is MSMT CSD SIFT2 Node Volume Weighted Streamline Count
print('mean')
print(df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].mean())
print('std')
print(df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].std())
print('max')
print(df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].max())
print('min')
print(df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].min())

# save out mean, std, max, min to csv
df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].mean().to_csv(main_path+'/stats/walk_4_count_paired_ttest_results_mean.csv')
df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].std().to_csv(main_path+'/stats/walk_4_count_paired_ttest_results_std.csv')
df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].max().to_csv(main_path+'/stats/walk_4_count_paired_ttest_results_max.csv')
df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].min().to_csv(main_path+'/stats/walk_4_count_paired_ttest_results_min.csv')
# Out:
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch41_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch91_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch11_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch65_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch29_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch90_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch55_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch63_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch12_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch56_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch48_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch86_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch69_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch28_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch72_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch99_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch27_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch33_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch18_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch26_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch21_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch66_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch43_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch83_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch51_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch97_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch61_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch34_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch74_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch47_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch84_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch54_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch96_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch58_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch37_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch22_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch75_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch32_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch36_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch23_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch40_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch71_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch49_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch81_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch92_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch15_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch59_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch64_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch62_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch31_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch67_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch14_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch60_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch52_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch44_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch93_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch42_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch39_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch50_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch19_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch78_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch53_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch82_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch57_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch46_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch16_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch77_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch80_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch73_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch17_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch94_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch87_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch76_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch35_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch13_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch45_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch79_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch85_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch24_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch38_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch20_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch95_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch30_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch89_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch68_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch10_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch25_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch88_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch98_walk_length_4_z_score_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/count_all_percent_batch70_walk_length_4_z_score_ttest_rel_results.csv
# mean
# T-statistic z-score t-test   -3.274979
# p-value z-score t-test        0.180431
# dtype: float64
# std
# T-statistic z-score t-test    3.198535
# p-value z-score t-test        0.330758
# dtype: float64
# max
# Recon 1                                  DTI Streamline Count
# Recon 2                       MSMT CSD SIFT2 Streamline Count
# T-statistic z-score t-test                           3.683914
# p-value z-score t-test                               0.999264
# dtype: object
# min
# Recon 1                                  DTI Streamline Count
# Recon 2                       MSMT CSD SIFT2 Streamline Count
# T-statistic z-score t-test                         -13.105167
# p-value z-score t-test                                    0.0
# dtype: object
# /tmp/ipykernel_1162134/348849612.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].mean())
# /tmp/ipykernel_1162134/348849612.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].std())
# /tmp/ipykernel_1162134/348849612.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].mean().to_csv(main_path+'/stats/walk_4_count_paired_ttest_results_mean.csv')
# /tmp/ipykernel_1162134/348849612.py:21: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['Recon 1']=='DTI Streamline Count') & (df['Recon 2']=='MSMT CSD SIFT2 Streamline Count')].std().to_csv(main_path+'/stats/walk_4_count_paired_ttest_results_std.csv')

# %%
# read in paired t-test results from all batches in main_path/stats with walk length 4
main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/'
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/'
file_list = Path(main_path+'/stats').glob('mean_length_*_walk_length_4_ttest_rel_results.csv')
df = pd.DataFrame()
for file in file_list:
    print(file)
    df = pd.concat([df,pd.read_csv(file)],axis=0)
# get mean and standard deviation, max, min of t-statistic and p-value for the row where Recon 1 is DTI Mean Length and Recon 2 is MSMT CSD SIFT2 Mean Length
print('mean')
print(df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].mean())
print('std')
print(df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].std())
print('max')
print(df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].max())
print('min')
print(df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].min())

# save out mean, std, max, min to one combined csv
df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].mean().to_csv(main_path+'/stats/walk_4_mean_length_paired_ttest_results_mean.csv')
df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].std().to_csv(main_path+'/stats/walk_4_mean_length_paired_ttest_results_std.csv')
df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].max().to_csv(main_path+'/stats/walk_4_mean_length_paired_ttest_results_max.csv')
df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].min().to_csv(main_path+'/stats/walk_4_mean_length_paired_ttest_results_min.csv')

# read in mean, std, max, and min csvs and save out to one combined csv
main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/'
# main_path = '/home/paul/thesis/dev/SAY_sf_prediction_v3/scrambled_dataset/stats/'
file_list = Path(main_path).glob('walk_4_mean_length_paired_ttest_results_*.csv')
df = pd.DataFrame()
for file in file_list:
    print(file)
    if 'mean.csv' in str(file):
        # set a column "Statistic" to "mean"
        df = pd.concat([df,pd.read_csv(file).assign(Statistic='mean')],axis=0)
    elif 'std.csv' in str(file):
        # set a column "Statistic" to "std"
        df = pd.concat([df,pd.read_csv(file).assign(Statistic='std')],axis=0)
    elif 'max.csv' in str(file):
        # set a column "Statistic" to "max"
        df = pd.concat([df,pd.read_csv(file).assign(Statistic='max')],axis=0)
    elif 'min.csv' in str(file):
        # set a column "Statistic" to "min"
        df = pd.concat([df,pd.read_csv(file).assign(Statistic='min')],axis=0)

df.to_csv(main_path+'walk_4_mean_length_paired_ttest_results.csv')
# Out:
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch68_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch28_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch52_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch72_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch53_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch98_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch70_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch81_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch15_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch39_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch24_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch90_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch73_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch97_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch54_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch99_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch95_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch35_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch69_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch59_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch27_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch77_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch46_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch55_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch89_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch21_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch22_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch40_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch18_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch36_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch25_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch47_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch57_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch62_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch91_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch19_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch61_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch86_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch60_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch84_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch17_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch37_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch74_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch11_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch34_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch56_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch94_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch43_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch85_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch93_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch38_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch63_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch26_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch65_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch75_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch41_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch48_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch10_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch64_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch83_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch76_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch50_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch33_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch16_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch71_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch44_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch30_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch14_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch79_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch42_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch51_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch67_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch58_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch20_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch23_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch82_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch92_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch29_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch45_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch31_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch96_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch66_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch13_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch88_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch87_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch78_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch80_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch32_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch12_walk_length_4_ttest_rel_results.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/mean_length_all_percent_batch49_walk_length_4_ttest_rel_results.csv
# mean
# T-statistic Pearson Score t-test   -5.282178
# p-value Pearson Score t-test        0.009403
# dtype: float64
# std
# T-statistic Pearson Score t-test    3.630968
# p-value Pearson Score t-test        0.028011
# dtype: float64
# max
# Recon 1                             MSMT CSD Mean Length
# Recon 2                                  DTI Mean Length
# T-statistic Pearson Score t-test               -1.202684
# p-value Pearson Score t-test                    0.121572
# dtype: object
# min
# Recon 1                             MSMT CSD Mean Length
# Recon 2                                  DTI Mean Length
# T-statistic Pearson Score t-test              -18.124181
# p-value Pearson Score t-test                         0.0
# dtype: object
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/walk_4_mean_length_paired_ttest_results_mean.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/walk_4_mean_length_paired_ttest_results_std.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/walk_4_mean_length_paired_ttest_results_max.csv
# /home/paul/thesis/dev/SAY_sf_prediction_v3/dataset/stats/walk_4_mean_length_paired_ttest_results_min.csv
# /tmp/ipykernel_1162134/1229272210.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].mean())
# /tmp/ipykernel_1162134/1229272210.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].std())
# /tmp/ipykernel_1162134/1229272210.py:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].mean().to_csv(main_path+'/stats/walk_4_mean_length_paired_ttest_results_mean.csv')
# /tmp/ipykernel_1162134/1229272210.py:21: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['Recon 2']=='DTI Mean Length') & (df['Recon 1']=='MSMT CSD Mean Length')].std().to_csv(main_path+'/stats/walk_4_mean_length_paired_ttest_results_std.csv')
